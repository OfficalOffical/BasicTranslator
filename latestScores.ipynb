# %% [markdown]
# <a href="https://colab.research.google.com/github/OfficalOffical/BasicTranslator/blob/master/latestScores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.src.regularizers import l1_l2, l2
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import Conv1D, BatchNormalization, Activation, MaxPooling1D, Flatten, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.src.saving.saving_api import load_model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.stats import zscore
import re


def work_on_outliers(input_df,inf_threshold,sup_threshold, feature_number,visualize):
    # WORKING ON OUTLIERS

    # Working on negpmax feature (the only one that is showing outliers)
    features = [f for f in input_df.columns[feature_number::4]]
    if visualize:
        fig, axes = plt.subplots(4, 3, figsize=(15, 10))  # Adjust the figsize as needed

        # Flatten the 2D array of subplots
        axes = axes.flatten()

    output_df=input_df.copy()

    for i, feature in enumerate(features):
        Q1 = input_df[feature].quantile(0.25)
        Q3 = input_df[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - inf_threshold * IQR

        if feature_number==3:
            upper_bound=0
        else:
            upper_bound=Q3 + sup_threshold * IQR




        # removing too  small values and positive values for negpmax
        #removing too large values for rms

        outliers = output_df[(output_df[feature] < lower_bound) | (output_df[feature] > upper_bound)]



        output_df = output_df[(output_df[feature] > lower_bound) & (output_df[feature] < upper_bound)]
        if visualize:
            axes[i].scatter(outliers["x"], outliers["y"], c=outliers[feature], cmap='viridis')  # Adjust the colormap as needed
            axes[i].set_title(f'REMOVED OUTLIERS: {feature}')
            axes[i].set_xlabel("X-axis")
            axes[i].set_ylabel("Y-axis")

    if visualize:
        plt.tight_layout()
        plt.show()


    if visualize:

        # let's see if the representation is working better after removing the outliers '
        random_10_percent = output_df.sample(frac=0.1, random_state=42)

        fig, axes = plt.subplots(4, 3, figsize=(15, 10))  # Adjust the figsize as needed
        fig.suptitle("RESULT AFTER REMOVING OUTLIERS (ON A 10% SAMPLE) ", fontsize=16)
        # Flatten the 2D array of subplots
        axes = axes.flatten()

        for i, feature in enumerate(features):
            axes[i].scatter(random_10_percent["x"], random_10_percent["y"], c=random_10_percent[feature],
                            cmap='viridis',label=feature)  # Adjust the colormap as needed
            axes[i].set_title(f'scatter plot: {feature}')
            axes[i].set_xlabel("X-axis")
            axes[i].set_ylabel("Y-axis")
            axes[i].legend(loc='best')  # Add legend

        # Adjust layout to prevent overlap
        plt.tight_layout()
        plt.show()


    return output_df


#MAIN CODE
def pre_process(df, normalize=False, see_graphs=False):
    #REMOVING NOISE COLUMNS

    #working on tmax features, which seem to be the most meaningful for removing the noise sensors
    z_scores = pd.DataFrame(zscore(df), columns=df.columns[5::5])
    outlier_threshold = 3
    outliers = (z_scores.abs() > outlier_threshold)

    #noise sensors have a random distribution of tmax, almost all  the values are contained
    #in the value of 3*dev_std. We order by increasing order of outliers and remove the columns
    #that have less outliers (random distribution)

    percentage_outliers = (outliers.sum() / len(df)) * 100
    sorted_columns = percentage_outliers.sort_values()
    numbers_to_remove = [re.search(r'\[(\d+)\]', column).group(1) for column in sorted_columns[:6].index]
    columns_to_drop = [column for column in df.columns if
                       any(re.search(rf'\[{number}\]', column) for number in numbers_to_remove)]

    df_clean = df.drop(columns=columns_to_drop)

    # the feature describing the area and the feature describing the pmax are highly correlated,
    # we can remove the area feature.

    features_area = [f for f in df_clean.columns[4::5]]

    df_clean = df_clean.drop(columns=features_area)

    #OUTLIERS

    # df_clean_out_negpmax=work_on_outliers(df_clean,25,0,3,see_graphs) #3 means negpmax

    #we can work also on the rms

    # df_clean_out_rms = work_on_outliers(df_clean, 1.5,1.5, 5,see_graphs)  # 5 means rms

    # SPLITTING AND NORMALIZING IF REQUIRED
    df_final=df_clean.copy()


    if normalize:
        scaler = StandardScaler()

        X_scaled = scaler.fit_transform(X)
    else:
        X_scaled= X.copy()



    return df_final

# %%
from tensorflow.keras.losses import Loss
import tensorflow.keras.backend as K
import pandas as pd
from keras import backend as K
import keras.saving
from keras.saving import load_model


@keras.saving.register_keras_serializable()
def euclidean_distance_loss(y_true, y_pred):
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1))

def euclidean_distance_error(y_true, y_pred):
    """
    Calculate the mean Euclidean distance error between true and predicted 2D points.
    :param y_true: Array of true values with shape (n_samples, 2).
    :param y_pred: Array of predicted values with shape (n_samples, 2).
    :return: Mean Euclidean distance error.
    """
    return np.mean(np.sqrt(np.sum(np.square(y_true - y_pred), axis=1)))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/development.csv')


'''columns_to_remove = ["pmax[0]", "negpmax[0]", "tmax[0]", "area[0]", "rms[0]",
                         "pmax[7]", "negpmax[7]", "tmax[7]", "area[7]", "rms[7]",
                         "pmax[12]", "negpmax[12]", "tmax[12]", "area[12]", "rms[12]",
                         "pmax[15]", "negpmax[15]", "tmax[15]", "area[15]", "rms[15]",
                         "pmax[16]", "negpmax[16]", "tmax[16]", "area[16]", "rms[16]",
                         "pmax[17]", "negpmax[17]", "tmax[17]", "area[17]", "rms[17]"]



df = df.drop(columns=columns_to_remove)

features_area = [f for f in df.columns[3::5]]

df = df.drop(columns=features_area)

print(df.shape)
df = df.dropna()
print(df.shape)'''

df = pre_process(df)



# Prepare the dataset
X = df.iloc[:, 2:].values
Y = df.iloc[:, :2].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)




# Further split training set to create a validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42) # Adjust the test_size as needed

# Reshape the data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='linear'))

# make the step of adam optimizer more smaller


# Compile the model
model.compile(optimizer='adam', loss=euclidean_distance_loss)

model.summary()


early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)

model.fit(X_train, Y_train, epochs=500, batch_size=32, validation_data=(X_val, Y_val), callbacks=[early_stopping,model_checkpoint], verbose=1)

# Evaluate the model
predictions = model.predict(X_test)

print(predictions)

mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               6272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 16674 (65.13 KB)
# Trainable params: 16674 (65.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/500
# 6947/6947 [==============================] - 24s 3ms/step - loss: 15.8343 - val_loss: 11.4106
# Epoch 2/500
# 6947/6947 [==============================] - 24s 3ms/step - loss: 10.1083 - val_loss: 8.5552
# Epoch 3/500
# 4692/6947 [===================>..........] - ETA: 11s - loss: 9.1906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6bb4f202e79d> in <cell line: 33>()
#      31 model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)
#      32
# ---> 33 model.fit(X_train, Y_train, epochs=500, batch_size=32, validation_data=(X_val, Y_val), callbacks=[early_stopping,model_checkpoint], verbose=1)
#      34
#      35 # Evaluate the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796                 callbacks.on_epoch_begin(epoch)
#    1797                 with data_handler.catch_stop_iteration():
# -> 1798                     for step in data_handler.steps():
#    1799                         with tf.profiler.experimental.Trace(
#    1800                             "train",
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in steps(self)
#    1409             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410                 break
# -> 1411             original_spe = self._steps_per_execution.numpy().item()
#    1412             can_run_full_execution = (
#    1413                 original_spe == 1
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     687   def numpy(self):
#     688     if context.executing_eagerly():
# --> 689       return self.read_value().numpy()
#     690     raise NotImplementedError(
#     691         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_value(self)
#     837     """
#     838     with ops.name_scope("Read"):
# --> 839       value = self._read_variable_op()
#     840     # Return an identity so it can get placed on whatever device the context
#     841     # specifies instead of the device where the variable is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _read_variable_op(self, no_copy)
#     816           result = read_and_set_handle(no_copy)
#     817     else:
# --> 818       result = read_and_set_handle(no_copy)
#     819
#     820     if not context.executing_eagerly():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_and_set_handle(no_copy)
#     806       if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     807         gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 808       result = gen_resource_variable_ops.read_variable_op(
#     809           self.handle, self._dtype)
#     810       _maybe_set_handle_data(self._dtype, self.handle, result)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_resource_variable_ops.py in read_variable_op(resource, dtype, name)
#     532   if tld.is_eager:
#     533     try:
# --> 534       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535         _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536       return _result
#
# KeyboardInterrupt:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)




# Further split training set to create a validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42) # Adjust the test_size as needed

# Reshape the data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

model = load_model('/content/best_model100.keras')

# Evaluate the model
predictions = model.predict(X_test)

print(predictions)

mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Further split training set to create a validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42) # Adjust the test_size as needed

# Reshape the data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# %%
model = Sequential([
    Conv1D(128, 3, input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling1D(3),
    Dropout(0.2),


    Conv1D(64, 3),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling1D(3),
    Dropout(0.2),




    Flatten(),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='linear')
])




model.compile(optimizer='adam', loss=euclidean_distance_loss)

model.summary()# assuming custom loss function

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model1010.keras', save_best_only=True)



model.fit(X_train, Y_train, epochs=500, batch_size=32, validation_data=(X_val, Y_val), callbacks=[early_stopping,model_checkpoint], verbose=1)
# Evaluate the model
predictions = model.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")

# %%
model = Sequential([





    Conv1D(64, 3, input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling1D(3),







    Flatten(),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='linear')
])




model.compile(optimizer=Adam(learning_rate=0.001), loss=euclidean_distance_loss)

model.summary()# assuming custom loss function

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model1002.keras', save_best_only=True)



model.fit(X_train, Y_train, epochs=550, batch_size=32, validation_data=(X_val, Y_val), callbacks=[early_stopping,model_checkpoint], verbose=1)
# Evaluate the model
predictions = model.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.externals import joblib

# Prepare the data for XGBoost
df = pd.read_csv('development.csv')
df = pre_process(df)
df = df.sample(n=50000, random_state=42)

X = df.iloc[:, 2:].values
Y = df.iloc[:, :2].values

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)


# Define the XGBoost model
model = xgb.XGBRegressor(objective=, colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# Fit the model
model.fit(X_train, Y_train, early_stopping_rounds=10, eval_set=[(X_val, Y_val)], verbose=True)

# Save the model
joblib.dump(model, "best_model.xgb")

# Evaluate the model
predictions = model.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from math import sqrt
import joblib  # Import joblib

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)



# Define the model
model = xgb.XGBRegressor(
    objective='reg:squarederror',
    colsample_bytree=0.5,  # Adjusted
    learning_rate=0.05,    # Lowered
    max_depth=6,           # Adjusted
    alpha=10,
    n_estimators=2000,     # Increased
    subsample=0.8,
    min_child_weight=1,    # New parameter
    gamma=0.1              # New parameter
)


# Fit the model
model.fit(X_train, Y_train, early_stopping_rounds=10, eval_set=[(X_val, Y_val)], verbose=True)

# Save the model
joblib.dump(model, "best_model.xgb")

# Evaluate the model
predictions = model.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")
# Out:
# [0]	validation_0-rmse:111.59383
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:106.16916
# [2]	validation_0-rmse:101.06038
# [3]	validation_0-rmse:96.16871
# [4]	validation_0-rmse:91.52126
# [5]	validation_0-rmse:87.07277
# [6]	validation_0-rmse:82.87988
# [7]	validation_0-rmse:78.90285
# [8]	validation_0-rmse:75.12546
# [9]	validation_0-rmse:71.51963
# [10]	validation_0-rmse:68.10857
# [11]	validation_0-rmse:64.85715
# [12]	validation_0-rmse:61.82016
# [13]	validation_0-rmse:58.88669
# [14]	validation_0-rmse:56.10601
# [15]	validation_0-rmse:53.43904
# [16]	validation_0-rmse:50.91345
# [17]	validation_0-rmse:48.50905
# [18]	validation_0-rmse:46.23949
# [19]	validation_0-rmse:44.08711
# [20]	validation_0-rmse:42.07191
# [21]	validation_0-rmse:40.10545
# [22]	validation_0-rmse:38.23457
# [23]	validation_0-rmse:36.48973
# [24]	validation_0-rmse:34.81007
# [25]	validation_0-rmse:33.22357
# [26]	validation_0-rmse:31.70963
# [27]	validation_0-rmse:30.27954
# [28]	validation_0-rmse:28.94536
# [29]	validation_0-rmse:27.65257
# [30]	validation_0-rmse:26.42255
# [31]	validation_0-rmse:25.26048
# [32]	validation_0-rmse:24.16874
# [33]	validation_0-rmse:23.12254
# [34]	validation_0-rmse:22.12005
# [35]	validation_0-rmse:21.19928
# [36]	validation_0-rmse:20.30109
# [37]	validation_0-rmse:19.45454
# [38]	validation_0-rmse:18.65644
# [39]	validation_0-rmse:17.90308
# [40]	validation_0-rmse:17.18488
# [41]	validation_0-rmse:16.51449
# [42]	validation_0-rmse:15.88060
# [43]	validation_0-rmse:15.27461
# [44]	validation_0-rmse:14.69633
# [45]	validation_0-rmse:14.16602
# [46]	validation_0-rmse:13.66521
# [47]	validation_0-rmse:13.18402
# [48]	validation_0-rmse:12.73299
# [49]	validation_0-rmse:12.31007
# [50]	validation_0-rmse:11.91790
# [51]	validation_0-rmse:11.54495
# [52]	validation_0-rmse:11.19013
# [53]	validation_0-rmse:10.84965
# [54]	validation_0-rmse:10.54181
# [55]	validation_0-rmse:10.24582
# [56]	validation_0-rmse:9.96979
# [57]	validation_0-rmse:9.72963
# [58]	validation_0-rmse:9.49689
# [59]	validation_0-rmse:9.26405
# [60]	validation_0-rmse:9.05414
# [61]	validation_0-rmse:8.86769
# [62]	validation_0-rmse:8.68192
# [63]	validation_0-rmse:8.50249
# [64]	validation_0-rmse:8.34383
# [65]	validation_0-rmse:8.19135
# [66]	validation_0-rmse:8.04702
# [67]	validation_0-rmse:7.91251
# [68]	validation_0-rmse:7.79011
# [69]	validation_0-rmse:7.67392
# [70]	validation_0-rmse:7.56302
# [71]	validation_0-rmse:7.45718
# [72]	validation_0-rmse:7.35480
# [73]	validation_0-rmse:7.26162
# [74]	validation_0-rmse:7.18158
# [75]	validation_0-rmse:7.10625
# [76]	validation_0-rmse:7.02805
# [77]	validation_0-rmse:6.95908
# [78]	validation_0-rmse:6.90336
# [79]	validation_0-rmse:6.84698
# [80]	validation_0-rmse:6.78721
# [81]	validation_0-rmse:6.73276
# [82]	validation_0-rmse:6.68459
# [83]	validation_0-rmse:6.63998
# [84]	validation_0-rmse:6.60017
# [85]	validation_0-rmse:6.55560
# [86]	validation_0-rmse:6.51225
# [87]	validation_0-rmse:6.47632
# [88]	validation_0-rmse:6.44684
# [89]	validation_0-rmse:6.41094
# [90]	validation_0-rmse:6.38164
# [91]	validation_0-rmse:6.35771
# [92]	validation_0-rmse:6.32885
# [93]	validation_0-rmse:6.30736
# [94]	validation_0-rmse:6.28353
# [95]	validation_0-rmse:6.26138
# [96]	validation_0-rmse:6.23244
# [97]	validation_0-rmse:6.20769
# [98]	validation_0-rmse:6.19104
# [99]	validation_0-rmse:6.17569
# [100]	validation_0-rmse:6.15604
# [101]	validation_0-rmse:6.13388
# [102]	validation_0-rmse:6.11387
# [103]	validation_0-rmse:6.09644
# [104]	validation_0-rmse:6.08278
# [105]	validation_0-rmse:6.06968
# [106]	validation_0-rmse:6.05211
# [107]	validation_0-rmse:6.03478
# [108]	validation_0-rmse:6.01663
# [109]	validation_0-rmse:6.00278
# [110]	validation_0-rmse:5.98595
# [111]	validation_0-rmse:5.97321
# [112]	validation_0-rmse:5.95930
# [113]	validation_0-rmse:5.94480
# [114]	validation_0-rmse:5.93022
# [115]	validation_0-rmse:5.91769
# [116]	validation_0-rmse:5.90873
# [117]	validation_0-rmse:5.89352
# [118]	validation_0-rmse:5.88254
# [119]	validation_0-rmse:5.87422
# [120]	validation_0-rmse:5.86518
# [121]	validation_0-rmse:5.85645
# [122]	validation_0-rmse:5.84576
# [123]	validation_0-rmse:5.83925
# [124]	validation_0-rmse:5.82911
# [125]	validation_0-rmse:5.82083
# [126]	validation_0-rmse:5.80750
# [127]	validation_0-rmse:5.79516
# [128]	validation_0-rmse:5.78109
# [129]	validation_0-rmse:5.77503
# [130]	validation_0-rmse:5.76467
# [131]	validation_0-rmse:5.75625
# [132]	validation_0-rmse:5.74936
# [133]	validation_0-rmse:5.74292
# [134]	validation_0-rmse:5.73231
# [135]	validation_0-rmse:5.72563
# [136]	validation_0-rmse:5.71567
# [137]	validation_0-rmse:5.70881
# [138]	validation_0-rmse:5.70223
# [139]	validation_0-rmse:5.69572
# [140]	validation_0-rmse:5.68867
# [141]	validation_0-rmse:5.68126
# [142]	validation_0-rmse:5.67617
# [143]	validation_0-rmse:5.67029
# [144]	validation_0-rmse:5.66075
# [145]	validation_0-rmse:5.65629
# [146]	validation_0-rmse:5.64758
# [147]	validation_0-rmse:5.63785
# [148]	validation_0-rmse:5.63218
# [149]	validation_0-rmse:5.62489
# [150]	validation_0-rmse:5.61872
# [151]	validation_0-rmse:5.60882
# [152]	validation_0-rmse:5.60552
# [153]	validation_0-rmse:5.59838
# [154]	validation_0-rmse:5.58850
# [155]	validation_0-rmse:5.57763
# [156]	validation_0-rmse:5.57286
# [157]	validation_0-rmse:5.56851
# [158]	validation_0-rmse:5.55877
# [159]	validation_0-rmse:5.55350
# [160]	validation_0-rmse:5.54676
# [161]	validation_0-rmse:5.53966
# [162]	validation_0-rmse:5.53172
# [163]	validation_0-rmse:5.52639
# [164]	validation_0-rmse:5.52047
# [165]	validation_0-rmse:5.51515
# [166]	validation_0-rmse:5.50696
# [167]	validation_0-rmse:5.50384
# [168]	validation_0-rmse:5.49668
# [169]	validation_0-rmse:5.49248
# [170]	validation_0-rmse:5.48649
# [171]	validation_0-rmse:5.48177
# [172]	validation_0-rmse:5.47748
# [173]	validation_0-rmse:5.47220
# [174]	validation_0-rmse:5.46681
# [175]	validation_0-rmse:5.46315
# [176]	validation_0-rmse:5.45806
# [177]	validation_0-rmse:5.45353
# [178]	validation_0-rmse:5.45115
# [179]	validation_0-rmse:5.44795
# [180]	validation_0-rmse:5.44282
# [181]	validation_0-rmse:5.43778
# [182]	validation_0-rmse:5.43118
# [183]	validation_0-rmse:5.42913
# [184]	validation_0-rmse:5.42190
# [185]	validation_0-rmse:5.41708
# [186]	validation_0-rmse:5.41137
# [187]	validation_0-rmse:5.40557
# [188]	validation_0-rmse:5.40117
# [189]	validation_0-rmse:5.39813
# [190]	validation_0-rmse:5.39357
# [191]	validation_0-rmse:5.39047
# [192]	validation_0-rmse:5.38363
# [193]	validation_0-rmse:5.37683
# [194]	validation_0-rmse:5.37356
# [195]	validation_0-rmse:5.36981
# [196]	validation_0-rmse:5.36571
# [197]	validation_0-rmse:5.36213
# [198]	validation_0-rmse:5.35952
# [199]	validation_0-rmse:5.35528
# [200]	validation_0-rmse:5.35031
# [201]	validation_0-rmse:5.34558
# [202]	validation_0-rmse:5.34088
# [203]	validation_0-rmse:5.33750
# [204]	validation_0-rmse:5.33330
# [205]	validation_0-rmse:5.32890
# [206]	validation_0-rmse:5.32518
# [207]	validation_0-rmse:5.31845
# [208]	validation_0-rmse:5.31343
# [209]	validation_0-rmse:5.30996
# [210]	validation_0-rmse:5.30663
# [211]	validation_0-rmse:5.30378
# [212]	validation_0-rmse:5.29947
# [213]	validation_0-rmse:5.29491
# [214]	validation_0-rmse:5.29177
# [215]	validation_0-rmse:5.28850
# [216]	validation_0-rmse:5.28228
# [217]	validation_0-rmse:5.27795
# [218]	validation_0-rmse:5.27203
# [219]	validation_0-rmse:5.26890
# [220]	validation_0-rmse:5.26643
# [221]	validation_0-rmse:5.26260
# [222]	validation_0-rmse:5.25932
# [223]	validation_0-rmse:5.25382
# [224]	validation_0-rmse:5.24985
# [225]	validation_0-rmse:5.24704
# [226]	validation_0-rmse:5.24175
# [227]	validation_0-rmse:5.23814
# [228]	validation_0-rmse:5.23329
# [229]	validation_0-rmse:5.22910
# [230]	validation_0-rmse:5.22379
# [231]	validation_0-rmse:5.22105
# [232]	validation_0-rmse:5.21714
# [233]	validation_0-rmse:5.21437
# [234]	validation_0-rmse:5.21224
# [235]	validation_0-rmse:5.20703
# [236]	validation_0-rmse:5.20284
# [237]	validation_0-rmse:5.19865
# [238]	validation_0-rmse:5.19491
# [239]	validation_0-rmse:5.19122
# [240]	validation_0-rmse:5.18891
# [241]	validation_0-rmse:5.18557
# [242]	validation_0-rmse:5.18306
# [243]	validation_0-rmse:5.17942
# [244]	validation_0-rmse:5.17528
# [245]	validation_0-rmse:5.17190
# [246]	validation_0-rmse:5.16919
# [247]	validation_0-rmse:5.16712
# [248]	validation_0-rmse:5.16354
# [249]	validation_0-rmse:5.15904
# [250]	validation_0-rmse:5.15399
# [251]	validation_0-rmse:5.14918
# [252]	validation_0-rmse:5.14700
# [253]	validation_0-rmse:5.14386
# [254]	validation_0-rmse:5.14056
# [255]	validation_0-rmse:5.13566
# [256]	validation_0-rmse:5.13299
# [257]	validation_0-rmse:5.12930
# [258]	validation_0-rmse:5.12690
# [259]	validation_0-rmse:5.12469
# [260]	validation_0-rmse:5.12172
# [261]	validation_0-rmse:5.11861
# [262]	validation_0-rmse:5.11597
# [263]	validation_0-rmse:5.11228
# [264]	validation_0-rmse:5.11007
# [265]	validation_0-rmse:5.10349
# [266]	validation_0-rmse:5.10172
# [267]	validation_0-rmse:5.09818
# [268]	validation_0-rmse:5.09560
# [269]	validation_0-rmse:5.09340
# [270]	validation_0-rmse:5.08880
# [271]	validation_0-rmse:5.08526
# [272]	validation_0-rmse:5.08329
# [273]	validation_0-rmse:5.07894
# [274]	validation_0-rmse:5.07542
# [275]	validation_0-rmse:5.07169
# [276]	validation_0-rmse:5.06923
# [277]	validation_0-rmse:5.06695
# [278]	validation_0-rmse:5.06229
# [279]	validation_0-rmse:5.05783
# [280]	validation_0-rmse:5.05447
# [281]	validation_0-rmse:5.05228
# [282]	validation_0-rmse:5.04952
# [283]	validation_0-rmse:5.04785
# [284]	validation_0-rmse:5.04615
# [285]	validation_0-rmse:5.04346
# [286]	validation_0-rmse:5.04008
# [287]	validation_0-rmse:5.03750
# [288]	validation_0-rmse:5.03470
# [289]	validation_0-rmse:5.03265
# [290]	validation_0-rmse:5.03049
# [291]	validation_0-rmse:5.02808
# [292]	validation_0-rmse:5.02560
# [293]	validation_0-rmse:5.02270
# [294]	validation_0-rmse:5.02098
# [295]	validation_0-rmse:5.01812
# [296]	validation_0-rmse:5.01606
# [297]	validation_0-rmse:5.01359
# [298]	validation_0-rmse:5.01156
# [299]	validation_0-rmse:5.00978
# [300]	validation_0-rmse:5.00790
# [301]	validation_0-rmse:5.00402
# [302]	validation_0-rmse:5.00096
# [303]	validation_0-rmse:4.99839
# [304]	validation_0-rmse:4.99601
# [305]	validation_0-rmse:4.99287
# [306]	validation_0-rmse:4.98958
# [307]	validation_0-rmse:4.98734
# [308]	validation_0-rmse:4.98412
# [309]	validation_0-rmse:4.98196
# [310]	validation_0-rmse:4.97958
# [311]	validation_0-rmse:4.97703
# [312]	validation_0-rmse:4.97432
# [313]	validation_0-rmse:4.97188
# [314]	validation_0-rmse:4.97005
# [315]	validation_0-rmse:4.96778
# [316]	validation_0-rmse:4.96497
# [317]	validation_0-rmse:4.96353
# [318]	validation_0-rmse:4.96039
# [319]	validation_0-rmse:4.95759
# [320]	validation_0-rmse:4.95607
# [321]	validation_0-rmse:4.95398
# [322]	validation_0-rmse:4.95099
# [323]	validation_0-rmse:4.94967
# [324]	validation_0-rmse:4.94739
# [325]	validation_0-rmse:4.94346
# [326]	validation_0-rmse:4.94162
# [327]	validation_0-rmse:4.93946
# [328]	validation_0-rmse:4.93706
# [329]	validation_0-rmse:4.93541
# [330]	validation_0-rmse:4.93305
# [331]	validation_0-rmse:4.93115
# [332]	validation_0-rmse:4.92943
# [333]	validation_0-rmse:4.92682
# [334]	validation_0-rmse:4.92488
# [335]	validation_0-rmse:4.92263
# [336]	validation_0-rmse:4.92106
# [337]	validation_0-rmse:4.91847
# [338]	validation_0-rmse:4.91586
# [339]	validation_0-rmse:4.91388
# [340]	validation_0-rmse:4.91150
# [341]	validation_0-rmse:4.90885
# [342]	validation_0-rmse:4.90653
# [343]	validation_0-rmse:4.90493
# [344]	validation_0-rmse:4.90294
# [345]	validation_0-rmse:4.90165
# [346]	validation_0-rmse:4.89941
# [347]	validation_0-rmse:4.89661
# [348]	validation_0-rmse:4.89566
# [349]	validation_0-rmse:4.89415
# [350]	validation_0-rmse:4.89200
# [351]	validation_0-rmse:4.88915
# [352]	validation_0-rmse:4.88707
# [353]	validation_0-rmse:4.88481
# [354]	validation_0-rmse:4.88344
# [355]	validation_0-rmse:4.88120
# [356]	validation_0-rmse:4.87969
# [357]	validation_0-rmse:4.87755
# [358]	validation_0-rmse:4.87563
# [359]	validation_0-rmse:4.87408
# [360]	validation_0-rmse:4.87207
# [361]	validation_0-rmse:4.87012
# [362]	validation_0-rmse:4.86908
# [363]	validation_0-rmse:4.86798
# [364]	validation_0-rmse:4.86561
# [365]	validation_0-rmse:4.86277
# [366]	validation_0-rmse:4.86192
# [367]	validation_0-rmse:4.86067
# [368]	validation_0-rmse:4.86009
# [369]	validation_0-rmse:4.85643
# [370]	validation_0-rmse:4.85449
# [371]	validation_0-rmse:4.85260
# [372]	validation_0-rmse:4.84950
# [373]	validation_0-rmse:4.84815
# [374]	validation_0-rmse:4.84640
# [375]	validation_0-rmse:4.84510
# [376]	validation_0-rmse:4.84266
# [377]	validation_0-rmse:4.84074
# [378]	validation_0-rmse:4.83871
# [379]	validation_0-rmse:4.83500
# [380]	validation_0-rmse:4.83242
# [381]	validation_0-rmse:4.83034
# [382]	validation_0-rmse:4.82795
# [383]	validation_0-rmse:4.82622
# [384]	validation_0-rmse:4.82494
# [385]	validation_0-rmse:4.82355
# [386]	validation_0-rmse:4.82151
# [387]	validation_0-rmse:4.81990
# [388]	validation_0-rmse:4.81924
# [389]	validation_0-rmse:4.81809
# [390]	validation_0-rmse:4.81652
# [391]	validation_0-rmse:4.81545
# [392]	validation_0-rmse:4.81387
# [393]	validation_0-rmse:4.81206
# [394]	validation_0-rmse:4.80910
# [395]	validation_0-rmse:4.80817
# [396]	validation_0-rmse:4.80607
# [397]	validation_0-rmse:4.80461
# [398]	validation_0-rmse:4.80317
# [399]	validation_0-rmse:4.80086
# [400]	validation_0-rmse:4.79922
# [401]	validation_0-rmse:4.79752
# [402]	validation_0-rmse:4.79637
# [403]	validation_0-rmse:4.79460
# [404]	validation_0-rmse:4.79390
# [405]	validation_0-rmse:4.79252
# [406]	validation_0-rmse:4.79067
# [407]	validation_0-rmse:4.78844
# [408]	validation_0-rmse:4.78724
# [409]	validation_0-rmse:4.78481
# [410]	validation_0-rmse:4.78357
# [411]	validation_0-rmse:4.78174
# [412]	validation_0-rmse:4.78028
# [413]	validation_0-rmse:4.77905
# [414]	validation_0-rmse:4.77788
# [415]	validation_0-rmse:4.77666
# [416]	validation_0-rmse:4.77458
# [417]	validation_0-rmse:4.77287
# [418]	validation_0-rmse:4.77093
# [419]	validation_0-rmse:4.77016
# [420]	validation_0-rmse:4.76810
# [421]	validation_0-rmse:4.76742
# [422]	validation_0-rmse:4.76512
# [423]	validation_0-rmse:4.76296
# [424]	validation_0-rmse:4.76181
# [425]	validation_0-rmse:4.76063
# [426]	validation_0-rmse:4.75971
# [427]	validation_0-rmse:4.75852
# [428]	validation_0-rmse:4.75658
# [429]	validation_0-rmse:4.75567
# [430]	validation_0-rmse:4.75493
# [431]	validation_0-rmse:4.75359
# [432]	validation_0-rmse:4.75225
# [433]	validation_0-rmse:4.75004
# [434]	validation_0-rmse:4.74885
# [435]	validation_0-rmse:4.74723
# [436]	validation_0-rmse:4.74526
# [437]	validation_0-rmse:4.74427
# [438]	validation_0-rmse:4.74178
# [439]	validation_0-rmse:4.74072
# [440]	validation_0-rmse:4.73878
# [441]	validation_0-rmse:4.73792
# [442]	validation_0-rmse:4.73640
# [443]	validation_0-rmse:4.73451
# [444]	validation_0-rmse:4.73272
# [445]	validation_0-rmse:4.73057
# [446]	validation_0-rmse:4.72897
# [447]	validation_0-rmse:4.72760
# [448]	validation_0-rmse:4.72606
# [449]	validation_0-rmse:4.72448
# [450]	validation_0-rmse:4.72340
# [451]	validation_0-rmse:4.72256
# [452]	validation_0-rmse:4.72115
# [453]	validation_0-rmse:4.71927
# [454]	validation_0-rmse:4.71751
# [455]	validation_0-rmse:4.71637
# [456]	validation_0-rmse:4.71578
# [457]	validation_0-rmse:4.71401
# [458]	validation_0-rmse:4.71207
# [459]	validation_0-rmse:4.71082
# [460]	validation_0-rmse:4.70959
# [461]	validation_0-rmse:4.70869
# [462]	validation_0-rmse:4.70756
# [463]	validation_0-rmse:4.70625
# [464]	validation_0-rmse:4.70482
# [465]	validation_0-rmse:4.70353
# [466]	validation_0-rmse:4.70289
# [467]	validation_0-rmse:4.70152
# [468]	validation_0-rmse:4.70043
# [469]	validation_0-rmse:4.69965
# [470]	validation_0-rmse:4.69908
# [471]	validation_0-rmse:4.69778
# [472]	validation_0-rmse:4.69588
# [473]	validation_0-rmse:4.69334
# [474]	validation_0-rmse:4.69253
# [475]	validation_0-rmse:4.69171
# [476]	validation_0-rmse:4.68989
# [477]	validation_0-rmse:4.68724
# [478]	validation_0-rmse:4.68556
# [479]	validation_0-rmse:4.68475
# [480]	validation_0-rmse:4.68337
# [481]	validation_0-rmse:4.68193
# [482]	validation_0-rmse:4.68101
# [483]	validation_0-rmse:4.68038
# [484]	validation_0-rmse:4.67904
# [485]	validation_0-rmse:4.67815
# [486]	validation_0-rmse:4.67717
# [487]	validation_0-rmse:4.67603
# [488]	validation_0-rmse:4.67549
# [489]	validation_0-rmse:4.67493
# [490]	validation_0-rmse:4.67361
# [491]	validation_0-rmse:4.67290
# [492]	validation_0-rmse:4.67203
# [493]	validation_0-rmse:4.67133
# [494]	validation_0-rmse:4.67048
# [495]	validation_0-rmse:4.66962
# [496]	validation_0-rmse:4.66791
# [497]	validation_0-rmse:4.66702
# [498]	validation_0-rmse:4.66601
# [499]	validation_0-rmse:4.66435
# [500]	validation_0-rmse:4.66287
# [501]	validation_0-rmse:4.66224
# [502]	validation_0-rmse:4.66112
# [503]	validation_0-rmse:4.65948
# [504]	validation_0-rmse:4.65863
# [505]	validation_0-rmse:4.65702
# [506]	validation_0-rmse:4.65623
# [507]	validation_0-rmse:4.65433
# [508]	validation_0-rmse:4.65287
# [509]	validation_0-rmse:4.65201
# [510]	validation_0-rmse:4.65106
# [511]	validation_0-rmse:4.65003
# [512]	validation_0-rmse:4.64874
# [513]	validation_0-rmse:4.64802
# [514]	validation_0-rmse:4.64661
# [515]	validation_0-rmse:4.64571
# [516]	validation_0-rmse:4.64477
# [517]	validation_0-rmse:4.64293
# [518]	validation_0-rmse:4.64245
# [519]	validation_0-rmse:4.64167
# [520]	validation_0-rmse:4.63977
# [521]	validation_0-rmse:4.63878
# [522]	validation_0-rmse:4.63740
# [523]	validation_0-rmse:4.63661
# [524]	validation_0-rmse:4.63541
# [525]	validation_0-rmse:4.63442
# [526]	validation_0-rmse:4.63346
# [527]	validation_0-rmse:4.63253
# [528]	validation_0-rmse:4.63133
# [529]	validation_0-rmse:4.63056
# [530]	validation_0-rmse:4.62978
# [531]	validation_0-rmse:4.62871
# [532]	validation_0-rmse:4.62802
# [533]	validation_0-rmse:4.62726
# [534]	validation_0-rmse:4.62629
# [535]	validation_0-rmse:4.62583
# [536]	validation_0-rmse:4.62484
# [537]	validation_0-rmse:4.62407
# [538]	validation_0-rmse:4.62284
# [539]	validation_0-rmse:4.62188
# [540]	validation_0-rmse:4.62086
# [541]	validation_0-rmse:4.62043
# [542]	validation_0-rmse:4.61952
# [543]	validation_0-rmse:4.61863
# [544]	validation_0-rmse:4.61697
# [545]	validation_0-rmse:4.61587
# [546]	validation_0-rmse:4.61507
# [547]	validation_0-rmse:4.61445
# [548]	validation_0-rmse:4.61282
# [549]	validation_0-rmse:4.61161
# [550]	validation_0-rmse:4.61104
# [551]	validation_0-rmse:4.61042
# [552]	validation_0-rmse:4.60997
# [553]	validation_0-rmse:4.60946
# [554]	validation_0-rmse:4.60875
# [555]	validation_0-rmse:4.60768
# [556]	validation_0-rmse:4.60679
# [557]	validation_0-rmse:4.60620
# [558]	validation_0-rmse:4.60533
# [559]	validation_0-rmse:4.60439
# [560]	validation_0-rmse:4.60275
# [561]	validation_0-rmse:4.60205
# [562]	validation_0-rmse:4.60132
# [563]	validation_0-rmse:4.60003
# [564]	validation_0-rmse:4.59927
# [565]	validation_0-rmse:4.59831
# [566]	validation_0-rmse:4.59698
# [567]	validation_0-rmse:4.59646
# [568]	validation_0-rmse:4.59573
# [569]	validation_0-rmse:4.59509
# [570]	validation_0-rmse:4.59418
# [571]	validation_0-rmse:4.59306
# [572]	validation_0-rmse:4.59228
# [573]	validation_0-rmse:4.59135
# [574]	validation_0-rmse:4.59060
# [575]	validation_0-rmse:4.58972
# [576]	validation_0-rmse:4.58867
# [577]	validation_0-rmse:4.58710
# [578]	validation_0-rmse:4.58569
# [579]	validation_0-rmse:4.58540
# [580]	validation_0-rmse:4.58422
# [581]	validation_0-rmse:4.58210
# [582]	validation_0-rmse:4.58125
# [583]	validation_0-rmse:4.58002
# [584]	validation_0-rmse:4.57850
# [585]	validation_0-rmse:4.57733
# [586]	validation_0-rmse:4.57677
# [587]	validation_0-rmse:4.57597
# [588]	validation_0-rmse:4.57538
# [589]	validation_0-rmse:4.57466
# [590]	validation_0-rmse:4.57382
# [591]	validation_0-rmse:4.57224
# [592]	validation_0-rmse:4.57144
# [593]	validation_0-rmse:4.57116
# [594]	validation_0-rmse:4.56998
# [595]	validation_0-rmse:4.56848
# [596]	validation_0-rmse:4.56684
# [597]	validation_0-rmse:4.56596
# [598]	validation_0-rmse:4.56485
# [599]	validation_0-rmse:4.56389
# [600]	validation_0-rmse:4.56339
# [601]	validation_0-rmse:4.56242
# [602]	validation_0-rmse:4.56139
# [603]	validation_0-rmse:4.56035
# [604]	validation_0-rmse:4.55957
# [605]	validation_0-rmse:4.55895
# [606]	validation_0-rmse:4.55827
# [607]	validation_0-rmse:4.55739
# [608]	validation_0-rmse:4.55639
# [609]	validation_0-rmse:4.55582
# [610]	validation_0-rmse:4.55447
# [611]	validation_0-rmse:4.55415
# [612]	validation_0-rmse:4.55327
# [613]	validation_0-rmse:4.55271
# [614]	validation_0-rmse:4.55190
# [615]	validation_0-rmse:4.55121
# [616]	validation_0-rmse:4.55072
# [617]	validation_0-rmse:4.55013
# [618]	validation_0-rmse:4.54875
# [619]	validation_0-rmse:4.54791
# [620]	validation_0-rmse:4.54703
# [621]	validation_0-rmse:4.54680
# [622]	validation_0-rmse:4.54608
# [623]	validation_0-rmse:4.54518
# [624]	validation_0-rmse:4.54471
# [625]	validation_0-rmse:4.54366
# [626]	validation_0-rmse:4.54234
# [627]	validation_0-rmse:4.54136
# [628]	validation_0-rmse:4.54067
# [629]	validation_0-rmse:4.53981
# [630]	validation_0-rmse:4.53887
# [631]	validation_0-rmse:4.53863
# [632]	validation_0-rmse:4.53778
# [633]	validation_0-rmse:4.53687
# [634]	validation_0-rmse:4.53627
# [635]	validation_0-rmse:4.53561
# [636]	validation_0-rmse:4.53472
# [637]	validation_0-rmse:4.53358
# [638]	validation_0-rmse:4.53297
# [639]	validation_0-rmse:4.53181
# [640]	validation_0-rmse:4.53132
# [641]	validation_0-rmse:4.52969
# [642]	validation_0-rmse:4.52865
# [643]	validation_0-rmse:4.52780
# [644]	validation_0-rmse:4.52734
# [645]	validation_0-rmse:4.52626
# [646]	validation_0-rmse:4.52603
# [647]	validation_0-rmse:4.52564
# [648]	validation_0-rmse:4.52450
# [649]	validation_0-rmse:4.52359
# [650]	validation_0-rmse:4.52235
# [651]	validation_0-rmse:4.52143
# [652]	validation_0-rmse:4.52040
# [653]	validation_0-rmse:4.51926
# [654]	validation_0-rmse:4.51848
# [655]	validation_0-rmse:4.51794
# [656]	validation_0-rmse:4.51666
# [657]	validation_0-rmse:4.51609
# [658]	validation_0-rmse:4.51434
# [659]	validation_0-rmse:4.51364
# [660]	validation_0-rmse:4.51260
# [661]	validation_0-rmse:4.51210
# [662]	validation_0-rmse:4.51138
# [663]	validation_0-rmse:4.51077
# [664]	validation_0-rmse:4.50988
# [665]	validation_0-rmse:4.50890
# [666]	validation_0-rmse:4.50817
# [667]	validation_0-rmse:4.50695
# [668]	validation_0-rmse:4.50599
# [669]	validation_0-rmse:4.50536
# [670]	validation_0-rmse:4.50441
# [671]	validation_0-rmse:4.50366
# [672]	validation_0-rmse:4.50262
# [673]	validation_0-rmse:4.50198
# [674]	validation_0-rmse:4.50127
# [675]	validation_0-rmse:4.50107
# [676]	validation_0-rmse:4.50018
# [677]	validation_0-rmse:4.49965
# [678]	validation_0-rmse:4.49846
# [679]	validation_0-rmse:4.49696
# [680]	validation_0-rmse:4.49559
# [681]	validation_0-rmse:4.49436
# [682]	validation_0-rmse:4.49264
# [683]	validation_0-rmse:4.49212
# [684]	validation_0-rmse:4.49105
# [685]	validation_0-rmse:4.48933
# [686]	validation_0-rmse:4.48820
# [687]	validation_0-rmse:4.48748
# [688]	validation_0-rmse:4.48723
# [689]	validation_0-rmse:4.48696
# [690]	validation_0-rmse:4.48614
# [691]	validation_0-rmse:4.48524
# [692]	validation_0-rmse:4.48475
# [693]	validation_0-rmse:4.48420
# [694]	validation_0-rmse:4.48394
# [695]	validation_0-rmse:4.48305
# [696]	validation_0-rmse:4.48246
# [697]	validation_0-rmse:4.48186
# [698]	validation_0-rmse:4.48143
# [699]	validation_0-rmse:4.48107
# [700]	validation_0-rmse:4.48005
# [701]	validation_0-rmse:4.47942
# [702]	validation_0-rmse:4.47882
# [703]	validation_0-rmse:4.47819
# [704]	validation_0-rmse:4.47745
# [705]	validation_0-rmse:4.47673
# [706]	validation_0-rmse:4.47634
# [707]	validation_0-rmse:4.47498
# [708]	validation_0-rmse:4.47462
# [709]	validation_0-rmse:4.47368
# [710]	validation_0-rmse:4.47288
# [711]	validation_0-rmse:4.47237
# [712]	validation_0-rmse:4.47135
# [713]	validation_0-rmse:4.47096
# [714]	validation_0-rmse:4.46994
# [715]	validation_0-rmse:4.46917
# [716]	validation_0-rmse:4.46864
# [717]	validation_0-rmse:4.46780
# [718]	validation_0-rmse:4.46655
# [719]	validation_0-rmse:4.46564
# [720]	validation_0-rmse:4.46488
# [721]	validation_0-rmse:4.46406
# [722]	validation_0-rmse:4.46388
# [723]	validation_0-rmse:4.46289
# [724]	validation_0-rmse:4.46234
# [725]	validation_0-rmse:4.46180
# [726]	validation_0-rmse:4.46110
# [727]	validation_0-rmse:4.46003
# [728]	validation_0-rmse:4.45928
# [729]	validation_0-rmse:4.45885
# [730]	validation_0-rmse:4.45830
# [731]	validation_0-rmse:4.45779
# [732]	validation_0-rmse:4.45703
# [733]	validation_0-rmse:4.45643
# [734]	validation_0-rmse:4.45565
# [735]	validation_0-rmse:4.45534
# [736]	validation_0-rmse:4.45460
# [737]	validation_0-rmse:4.45423
# [738]	validation_0-rmse:4.45374
# [739]	validation_0-rmse:4.45324
# [740]	validation_0-rmse:4.45244
# [741]	validation_0-rmse:4.45209
# [742]	validation_0-rmse:4.45167
# [743]	validation_0-rmse:4.45132
# [744]	validation_0-rmse:4.45015
# [745]	validation_0-rmse:4.44934
# [746]	validation_0-rmse:4.44897
# [747]	validation_0-rmse:4.44829
# [748]	validation_0-rmse:4.44756
# [749]	validation_0-rmse:4.44667
# [750]	validation_0-rmse:4.44610
# [751]	validation_0-rmse:4.44551
# [752]	validation_0-rmse:4.44479
# [753]	validation_0-rmse:4.44339
# [754]	validation_0-rmse:4.44243
# [755]	validation_0-rmse:4.44212
# [756]	validation_0-rmse:4.44146
# [757]	validation_0-rmse:4.44072
# [758]	validation_0-rmse:4.44008
# [759]	validation_0-rmse:4.43887
# [760]	validation_0-rmse:4.43779
# [761]	validation_0-rmse:4.43708
# [762]	validation_0-rmse:4.43642
# [763]	validation_0-rmse:4.43589
# [764]	validation_0-rmse:4.43533
# [765]	validation_0-rmse:4.43451
# [766]	validation_0-rmse:4.43376
# [767]	validation_0-rmse:4.43320
# [768]	validation_0-rmse:4.43296
# [769]	validation_0-rmse:4.43218
# [770]	validation_0-rmse:4.43146
# [771]	validation_0-rmse:4.43109
# [772]	validation_0-rmse:4.42990
# [773]	validation_0-rmse:4.42953
# [774]	validation_0-rmse:4.42892
# [775]	validation_0-rmse:4.42798
# [776]	validation_0-rmse:4.42721
# [777]	validation_0-rmse:4.42635
# [778]	validation_0-rmse:4.42527
# [779]	validation_0-rmse:4.42448
# [780]	validation_0-rmse:4.42344
# [781]	validation_0-rmse:4.42308
# [782]	validation_0-rmse:4.42245
# [783]	validation_0-rmse:4.42131
# [784]	validation_0-rmse:4.42103
# [785]	validation_0-rmse:4.42080
# [786]	validation_0-rmse:4.42036
# [787]	validation_0-rmse:4.41944
# [788]	validation_0-rmse:4.41862
# [789]	validation_0-rmse:4.41812
# [790]	validation_0-rmse:4.41737
# [791]	validation_0-rmse:4.41679
# [792]	validation_0-rmse:4.41608
# [793]	validation_0-rmse:4.41543
# [794]	validation_0-rmse:4.41486
# [795]	validation_0-rmse:4.41384
# [796]	validation_0-rmse:4.41348
# [797]	validation_0-rmse:4.41300
# [798]	validation_0-rmse:4.41259
# [799]	validation_0-rmse:4.41194
# [800]	validation_0-rmse:4.41158
# [801]	validation_0-rmse:4.41112
# [802]	validation_0-rmse:4.41060
# [803]	validation_0-rmse:4.40935
# [804]	validation_0-rmse:4.40881
# [805]	validation_0-rmse:4.40824
# [806]	validation_0-rmse:4.40757
# [807]	validation_0-rmse:4.40688
# [808]	validation_0-rmse:4.40610
# [809]	validation_0-rmse:4.40534
# [810]	validation_0-rmse:4.40461
# [811]	validation_0-rmse:4.40385
# [812]	validation_0-rmse:4.40335
# [813]	validation_0-rmse:4.40224
# [814]	validation_0-rmse:4.40148
# [815]	validation_0-rmse:4.40094
# [816]	validation_0-rmse:4.40052
# [817]	validation_0-rmse:4.40040
# [818]	validation_0-rmse:4.39977
# [819]	validation_0-rmse:4.39932
# [820]	validation_0-rmse:4.39829
# [821]	validation_0-rmse:4.39762
# [822]	validation_0-rmse:4.39705
# [823]	validation_0-rmse:4.39622
# [824]	validation_0-rmse:4.39565
# [825]	validation_0-rmse:4.39512
# [826]	validation_0-rmse:4.39441
# [827]	validation_0-rmse:4.39390
# [828]	validation_0-rmse:4.39310
# [829]	validation_0-rmse:4.39235
# [830]	validation_0-rmse:4.39161
# [831]	validation_0-rmse:4.39088
# [832]	validation_0-rmse:4.39077
# [833]	validation_0-rmse:4.39016
# [834]	validation_0-rmse:4.38944
# [835]	validation_0-rmse:4.38876
# [836]	validation_0-rmse:4.38853
# [837]	validation_0-rmse:4.38799
# [838]	validation_0-rmse:4.38725
# [839]	validation_0-rmse:4.38628
# [840]	validation_0-rmse:4.38574
# [841]	validation_0-rmse:4.38506
# [842]	validation_0-rmse:4.38444
# [843]	validation_0-rmse:4.38388
# [844]	validation_0-rmse:4.38324
# [845]	validation_0-rmse:4.38289
# [846]	validation_0-rmse:4.38246
# [847]	validation_0-rmse:4.38207
# [848]	validation_0-rmse:4.38184
# [849]	validation_0-rmse:4.38084
# [850]	validation_0-rmse:4.38052
# [851]	validation_0-rmse:4.38022
# [852]	validation_0-rmse:4.37999
# [853]	validation_0-rmse:4.37909
# [854]	validation_0-rmse:4.37879
# [855]	validation_0-rmse:4.37801
# [856]	validation_0-rmse:4.37773
# [857]	validation_0-rmse:4.37739
# [858]	validation_0-rmse:4.37678
# [859]	validation_0-rmse:4.37643
# [860]	validation_0-rmse:4.37546
# [861]	validation_0-rmse:4.37481
# [862]	validation_0-rmse:4.37458
# [863]	validation_0-rmse:4.37414
# [864]	validation_0-rmse:4.37358
# [865]	validation_0-rmse:4.37292
# [866]	validation_0-rmse:4.37254
# [867]	validation_0-rmse:4.37194
# [868]	validation_0-rmse:4.37160
# [869]	validation_0-rmse:4.37117
# [870]	validation_0-rmse:4.37094
# [871]	validation_0-rmse:4.37060
# [872]	validation_0-rmse:4.36979
# [873]	validation_0-rmse:4.36930
# [874]	validation_0-rmse:4.36896
# [875]	validation_0-rmse:4.36783
# [876]	validation_0-rmse:4.36743
# [877]	validation_0-rmse:4.36670
# [878]	validation_0-rmse:4.36660
# [879]	validation_0-rmse:4.36634
# [880]	validation_0-rmse:4.36563
# [881]	validation_0-rmse:4.36429
# [882]	validation_0-rmse:4.36406
# [883]	validation_0-rmse:4.36368
# [884]	validation_0-rmse:4.36345
# [885]	validation_0-rmse:4.36281
# [886]	validation_0-rmse:4.36223
# [887]	validation_0-rmse:4.36190
# [888]	validation_0-rmse:4.36133
# [889]	validation_0-rmse:4.36069
# [890]	validation_0-rmse:4.36002
# [891]	validation_0-rmse:4.35960
# [892]	validation_0-rmse:4.35863
# [893]	validation_0-rmse:4.35795
# [894]	validation_0-rmse:4.35719
# [895]	validation_0-rmse:4.35688
# [896]	validation_0-rmse:4.35605
# [897]	validation_0-rmse:4.35530
# [898]	validation_0-rmse:4.35513
# [899]	validation_0-rmse:4.35384
# [900]	validation_0-rmse:4.35334
# [901]	validation_0-rmse:4.35283
# [902]	validation_0-rmse:4.35233
# [903]	validation_0-rmse:4.35185
# [904]	validation_0-rmse:4.35116
# [905]	validation_0-rmse:4.35063
# [906]	validation_0-rmse:4.34980
# [907]	validation_0-rmse:4.34958
# [908]	validation_0-rmse:4.34932
# [909]	validation_0-rmse:4.34836
# [910]	validation_0-rmse:4.34800
# [911]	validation_0-rmse:4.34762
# [912]	validation_0-rmse:4.34731
# [913]	validation_0-rmse:4.34690
# [914]	validation_0-rmse:4.34639
# [915]	validation_0-rmse:4.34566
# [916]	validation_0-rmse:4.34535
# [917]	validation_0-rmse:4.34487
# [918]	validation_0-rmse:4.34483
# [919]	validation_0-rmse:4.34464
# [920]	validation_0-rmse:4.34401
# [921]	validation_0-rmse:4.34360
# [922]	validation_0-rmse:4.34310
# [923]	validation_0-rmse:4.34231
# [924]	validation_0-rmse:4.34218
# [925]	validation_0-rmse:4.34135
# [926]	validation_0-rmse:4.34078
# [927]	validation_0-rmse:4.34021
# [928]	validation_0-rmse:4.33971
# [929]	validation_0-rmse:4.33919
# [930]	validation_0-rmse:4.33911
# [931]	validation_0-rmse:4.33840
# [932]	validation_0-rmse:4.33799
# [933]	validation_0-rmse:4.33724
# [934]	validation_0-rmse:4.33675
# [935]	validation_0-rmse:4.33619
# [936]	validation_0-rmse:4.33589
# [937]	validation_0-rmse:4.33537
# [938]	validation_0-rmse:4.33491
# [939]	validation_0-rmse:4.33447
# [940]	validation_0-rmse:4.33396
# [941]	validation_0-rmse:4.33349
# [942]	validation_0-rmse:4.33311
# [943]	validation_0-rmse:4.33287
# [944]	validation_0-rmse:4.33219
# [945]	validation_0-rmse:4.33166
# [946]	validation_0-rmse:4.33138
# [947]	validation_0-rmse:4.33054
# [948]	validation_0-rmse:4.33020
# [949]	validation_0-rmse:4.32977
# [950]	validation_0-rmse:4.32944
# [951]	validation_0-rmse:4.32928
# [952]	validation_0-rmse:4.32881
# [953]	validation_0-rmse:4.32827
# [954]	validation_0-rmse:4.32782
# [955]	validation_0-rmse:4.32727
# [956]	validation_0-rmse:4.32660
# [957]	validation_0-rmse:4.32622
# [958]	validation_0-rmse:4.32530
# [959]	validation_0-rmse:4.32508
# [960]	validation_0-rmse:4.32478
# [961]	validation_0-rmse:4.32414
# [962]	validation_0-rmse:4.32388
# [963]	validation_0-rmse:4.32309
# [964]	validation_0-rmse:4.32275
# [965]	validation_0-rmse:4.32209
# [966]	validation_0-rmse:4.32158
# [967]	validation_0-rmse:4.32138
# [968]	validation_0-rmse:4.32122
# [969]	validation_0-rmse:4.32065
# [970]	validation_0-rmse:4.32035
# [971]	validation_0-rmse:4.31987
# [972]	validation_0-rmse:4.31932
# [973]	validation_0-rmse:4.31905
# [974]	validation_0-rmse:4.31864
# [975]	validation_0-rmse:4.31817
# [976]	validation_0-rmse:4.31747
# [977]	validation_0-rmse:4.31736
# [978]	validation_0-rmse:4.31665
# [979]	validation_0-rmse:4.31639
# [980]	validation_0-rmse:4.31632
# [981]	validation_0-rmse:4.31583
# [982]	validation_0-rmse:4.31542
# [983]	validation_0-rmse:4.31439
# [984]	validation_0-rmse:4.31395
# [985]	validation_0-rmse:4.31345
# [986]	validation_0-rmse:4.31270
# [987]	validation_0-rmse:4.31245
# [988]	validation_0-rmse:4.31231
# [989]	validation_0-rmse:4.31182
# [990]	validation_0-rmse:4.31104
# [991]	validation_0-rmse:4.31015
# [992]	validation_0-rmse:4.30942
# [993]	validation_0-rmse:4.30915
# [994]	validation_0-rmse:4.30858
# [995]	validation_0-rmse:4.30786
# [996]	validation_0-rmse:4.30705
# [997]	validation_0-rmse:4.30648
# [998]	validation_0-rmse:4.30602
# [999]	validation_0-rmse:4.30566
# [1000]	validation_0-rmse:4.30482
# [1001]	validation_0-rmse:4.30412
# [1002]	validation_0-rmse:4.30365
# [1003]	validation_0-rmse:4.30322
# [1004]	validation_0-rmse:4.30255
# [1005]	validation_0-rmse:4.30228
# [1006]	validation_0-rmse:4.30141
# [1007]	validation_0-rmse:4.30126
# [1008]	validation_0-rmse:4.30076
# [1009]	validation_0-rmse:4.30048
# [1010]	validation_0-rmse:4.29982
# [1011]	validation_0-rmse:4.29960
# [1012]	validation_0-rmse:4.29869
# [1013]	validation_0-rmse:4.29846
# [1014]	validation_0-rmse:4.29800
# [1015]	validation_0-rmse:4.29725
# [1016]	validation_0-rmse:4.29693
# [1017]	validation_0-rmse:4.29645
# [1018]	validation_0-rmse:4.29592
# [1019]	validation_0-rmse:4.29569
# [1020]	validation_0-rmse:4.29539
# [1021]	validation_0-rmse:4.29523
# [1022]	validation_0-rmse:4.29452
# [1023]	validation_0-rmse:4.29408
# [1024]	validation_0-rmse:4.29386
# [1025]	validation_0-rmse:4.29371
# [1026]	validation_0-rmse:4.29339
# [1027]	validation_0-rmse:4.29311
# [1028]	validation_0-rmse:4.29280
# [1029]	validation_0-rmse:4.29274
# [1030]	validation_0-rmse:4.29215
# [1031]	validation_0-rmse:4.29174
# [1032]	validation_0-rmse:4.29161
# [1033]	validation_0-rmse:4.29106
# [1034]	validation_0-rmse:4.29061
# [1035]	validation_0-rmse:4.29045
# [1036]	validation_0-rmse:4.29002
# [1037]	validation_0-rmse:4.28978
# [1038]	validation_0-rmse:4.28956
# [1039]	validation_0-rmse:4.28940
# [1040]	validation_0-rmse:4.28889
# [1041]	validation_0-rmse:4.28868
# [1042]	validation_0-rmse:4.28790
# [1043]	validation_0-rmse:4.28769
# [1044]	validation_0-rmse:4.28755
# [1045]	validation_0-rmse:4.28699
# [1046]	validation_0-rmse:4.28657
# [1047]	validation_0-rmse:4.28622
# [1048]	validation_0-rmse:4.28589
# [1049]	validation_0-rmse:4.28556
# [1050]	validation_0-rmse:4.28503
# [1051]	validation_0-rmse:4.28462
# [1052]	validation_0-rmse:4.28456
# [1053]	validation_0-rmse:4.28428
# [1054]	validation_0-rmse:4.28383
# [1055]	validation_0-rmse:4.28345
# [1056]	validation_0-rmse:4.28315
# [1057]	validation_0-rmse:4.28299
# [1058]	validation_0-rmse:4.28264
# [1059]	validation_0-rmse:4.28209
# [1060]	validation_0-rmse:4.28194
# [1061]	validation_0-rmse:4.28181
# [1062]	validation_0-rmse:4.28164
# [1063]	validation_0-rmse:4.28114
# [1064]	validation_0-rmse:4.28098
# [1065]	validation_0-rmse:4.28056
# [1066]	validation_0-rmse:4.28026
# [1067]	validation_0-rmse:4.27970
# [1068]	validation_0-rmse:4.27871
# [1069]	validation_0-rmse:4.27816
# [1070]	validation_0-rmse:4.27765
# [1071]	validation_0-rmse:4.27762
# [1072]	validation_0-rmse:4.27740
# [1073]	validation_0-rmse:4.27729
# [1074]	validation_0-rmse:4.27685
# [1075]	validation_0-rmse:4.27664
# [1076]	validation_0-rmse:4.27642
# [1077]	validation_0-rmse:4.27633
# [1078]	validation_0-rmse:4.27599
# [1079]	validation_0-rmse:4.27570
# [1080]	validation_0-rmse:4.27568
# [1081]	validation_0-rmse:4.27478
# [1082]	validation_0-rmse:4.27433
# [1083]	validation_0-rmse:4.27382
# [1084]	validation_0-rmse:4.27325
# [1085]	validation_0-rmse:4.27232
# [1086]	validation_0-rmse:4.27220
# [1087]	validation_0-rmse:4.27188
# [1088]	validation_0-rmse:4.27134
# [1089]	validation_0-rmse:4.27097
# [1090]	validation_0-rmse:4.27070
# [1091]	validation_0-rmse:4.27061
# [1092]	validation_0-rmse:4.27034
# [1093]	validation_0-rmse:4.27004
# [1094]	validation_0-rmse:4.27002
# [1095]	validation_0-rmse:4.26904
# [1096]	validation_0-rmse:4.26876
# [1097]	validation_0-rmse:4.26795
# [1098]	validation_0-rmse:4.26758
# [1099]	validation_0-rmse:4.26735
# [1100]	validation_0-rmse:4.26683
# [1101]	validation_0-rmse:4.26655
# [1102]	validation_0-rmse:4.26630
# [1103]	validation_0-rmse:4.26586
# [1104]	validation_0-rmse:4.26536
# [1105]	validation_0-rmse:4.26511
# [1106]	validation_0-rmse:4.26484
# [1107]	validation_0-rmse:4.26450
# [1108]	validation_0-rmse:4.26411
# [1109]	validation_0-rmse:4.26374
# [1110]	validation_0-rmse:4.26303
# [1111]	validation_0-rmse:4.26273
# [1112]	validation_0-rmse:4.26253
# [1113]	validation_0-rmse:4.26222
# [1114]	validation_0-rmse:4.26149
# [1115]	validation_0-rmse:4.26092
# [1116]	validation_0-rmse:4.26081
# [1117]	validation_0-rmse:4.26059
# [1118]	validation_0-rmse:4.26023
# [1119]	validation_0-rmse:4.26002
# [1120]	validation_0-rmse:4.25951
# [1121]	validation_0-rmse:4.25922
# [1122]	validation_0-rmse:4.25877
# [1123]	validation_0-rmse:4.25872
# [1124]	validation_0-rmse:4.25820
# [1125]	validation_0-rmse:4.25790
# [1126]	validation_0-rmse:4.25758
# [1127]	validation_0-rmse:4.25675
# [1128]	validation_0-rmse:4.25646
# [1129]	validation_0-rmse:4.25607
# [1130]	validation_0-rmse:4.25559
# [1131]	validation_0-rmse:4.25485
# [1132]	validation_0-rmse:4.25465
# [1133]	validation_0-rmse:4.25438
# [1134]	validation_0-rmse:4.25368
# [1135]	validation_0-rmse:4.25358
# [1136]	validation_0-rmse:4.25297
# [1137]	validation_0-rmse:4.25263
# [1138]	validation_0-rmse:4.25256
# [1139]	validation_0-rmse:4.25251
# [1140]	validation_0-rmse:4.25224
# [1141]	validation_0-rmse:4.25187
# [1142]	validation_0-rmse:4.25149
# [1143]	validation_0-rmse:4.25104
# [1144]	validation_0-rmse:4.25064
# [1145]	validation_0-rmse:4.25032
# [1146]	validation_0-rmse:4.24998
# [1147]	validation_0-rmse:4.24959
# [1148]	validation_0-rmse:4.24911
# [1149]	validation_0-rmse:4.24862
# [1150]	validation_0-rmse:4.24837
# [1151]	validation_0-rmse:4.24780
# [1152]	validation_0-rmse:4.24730
# [1153]	validation_0-rmse:4.24680
# [1154]	validation_0-rmse:4.24674
# [1155]	validation_0-rmse:4.24652
# [1156]	validation_0-rmse:4.24621
# [1157]	validation_0-rmse:4.24601
# [1158]	validation_0-rmse:4.24564
# [1159]	validation_0-rmse:4.24543
# [1160]	validation_0-rmse:4.24490
# [1161]	validation_0-rmse:4.24425
# [1162]	validation_0-rmse:4.24378
# [1163]	validation_0-rmse:4.24331
# [1164]	validation_0-rmse:4.24320
# [1165]	validation_0-rmse:4.24298
# [1166]	validation_0-rmse:4.24282
# [1167]	validation_0-rmse:4.24282
# [1168]	validation_0-rmse:4.24234
# [1169]	validation_0-rmse:4.24217
# [1170]	validation_0-rmse:4.24167
# [1171]	validation_0-rmse:4.24146
# [1172]	validation_0-rmse:4.24121
# [1173]	validation_0-rmse:4.24108
# [1174]	validation_0-rmse:4.24104
# [1175]	validation_0-rmse:4.24091
# [1176]	validation_0-rmse:4.24052
# [1177]	validation_0-rmse:4.24024
# [1178]	validation_0-rmse:4.24015
# [1179]	validation_0-rmse:4.23963
# [1180]	validation_0-rmse:4.23905
# [1181]	validation_0-rmse:4.23855
# [1182]	validation_0-rmse:4.23802
# [1183]	validation_0-rmse:4.23747
# [1184]	validation_0-rmse:4.23690
# [1185]	validation_0-rmse:4.23675
# [1186]	validation_0-rmse:4.23648
# [1187]	validation_0-rmse:4.23614
# [1188]	validation_0-rmse:4.23569
# [1189]	validation_0-rmse:4.23528
# [1190]	validation_0-rmse:4.23483
# [1191]	validation_0-rmse:4.23468
# [1192]	validation_0-rmse:4.23441
# [1193]	validation_0-rmse:4.23397
# [1194]	validation_0-rmse:4.23382
# [1195]	validation_0-rmse:4.23345
# [1196]	validation_0-rmse:4.23292
# [1197]	validation_0-rmse:4.23246
# [1198]	validation_0-rmse:4.23212
# [1199]	validation_0-rmse:4.23198
# [1200]	validation_0-rmse:4.23164
# [1201]	validation_0-rmse:4.23133
# [1202]	validation_0-rmse:4.23094
# [1203]	validation_0-rmse:4.23086
# [1204]	validation_0-rmse:4.23067
# [1205]	validation_0-rmse:4.23033
# [1206]	validation_0-rmse:4.23007
# [1207]	validation_0-rmse:4.22932
# [1208]	validation_0-rmse:4.22894
# [1209]	validation_0-rmse:4.22875
# [1210]	validation_0-rmse:4.22858
# [1211]	validation_0-rmse:4.22849
# [1212]	validation_0-rmse:4.22833
# [1213]	validation_0-rmse:4.22785
# [1214]	validation_0-rmse:4.22771
# [1215]	validation_0-rmse:4.22752
# [1216]	validation_0-rmse:4.22716
# [1217]	validation_0-rmse:4.22690
# [1218]	validation_0-rmse:4.22678
# [1219]	validation_0-rmse:4.22658
# [1220]	validation_0-rmse:4.22640
# [1221]	validation_0-rmse:4.22555
# [1222]	validation_0-rmse:4.22540
# [1223]	validation_0-rmse:4.22515
# [1224]	validation_0-rmse:4.22472
# [1225]	validation_0-rmse:4.22445
# [1226]	validation_0-rmse:4.22407
# [1227]	validation_0-rmse:4.22370
# [1228]	validation_0-rmse:4.22365
# [1229]	validation_0-rmse:4.22308
# [1230]	validation_0-rmse:4.22282
# [1231]	validation_0-rmse:4.22269
# [1232]	validation_0-rmse:4.22253
# [1233]	validation_0-rmse:4.22221
# [1234]	validation_0-rmse:4.22175
# [1235]	validation_0-rmse:4.22156
# [1236]	validation_0-rmse:4.22089
# [1237]	validation_0-rmse:4.22040
# [1238]	validation_0-rmse:4.21991
# [1239]	validation_0-rmse:4.21961
# [1240]	validation_0-rmse:4.21932
# [1241]	validation_0-rmse:4.21887
# [1242]	validation_0-rmse:4.21820
# [1243]	validation_0-rmse:4.21795
# [1244]	validation_0-rmse:4.21751
# [1245]	validation_0-rmse:4.21709
# [1246]	validation_0-rmse:4.21646
# [1247]	validation_0-rmse:4.21597
# [1248]	validation_0-rmse:4.21569
# [1249]	validation_0-rmse:4.21526
# [1250]	validation_0-rmse:4.21517
# [1251]	validation_0-rmse:4.21464
# [1252]	validation_0-rmse:4.21445
# [1253]	validation_0-rmse:4.21428
# [1254]	validation_0-rmse:4.21413
# [1255]	validation_0-rmse:4.21376
# [1256]	validation_0-rmse:4.21351
# [1257]	validation_0-rmse:4.21311
# [1258]	validation_0-rmse:4.21255
# [1259]	validation_0-rmse:4.21215
# [1260]	validation_0-rmse:4.21187
# [1261]	validation_0-rmse:4.21152
# [1262]	validation_0-rmse:4.21146
# [1263]	validation_0-rmse:4.21111
# [1264]	validation_0-rmse:4.21106
# [1265]	validation_0-rmse:4.21080
# [1266]	validation_0-rmse:4.21047
# [1267]	validation_0-rmse:4.21013
# [1268]	validation_0-rmse:4.20942
# [1269]	validation_0-rmse:4.20912
# [1270]	validation_0-rmse:4.20867
# [1271]	validation_0-rmse:4.20845
# [1272]	validation_0-rmse:4.20804
# [1273]	validation_0-rmse:4.20766
# [1274]	validation_0-rmse:4.20719
# [1275]	validation_0-rmse:4.20702
# [1276]	validation_0-rmse:4.20700
# [1277]	validation_0-rmse:4.20684
# [1278]	validation_0-rmse:4.20660
# [1279]	validation_0-rmse:4.20627
# [1280]	validation_0-rmse:4.20618
# [1281]	validation_0-rmse:4.20594
# [1282]	validation_0-rmse:4.20571
# [1283]	validation_0-rmse:4.20556
# [1284]	validation_0-rmse:4.20535
# [1285]	validation_0-rmse:4.20496
# [1286]	validation_0-rmse:4.20467
# [1287]	validation_0-rmse:4.20454
# [1288]	validation_0-rmse:4.20439
# [1289]	validation_0-rmse:4.20400
# [1290]	validation_0-rmse:4.20369
# [1291]	validation_0-rmse:4.20328
# [1292]	validation_0-rmse:4.20294
# [1293]	validation_0-rmse:4.20232
# [1294]	validation_0-rmse:4.20229
# [1295]	validation_0-rmse:4.20190
# [1296]	validation_0-rmse:4.20171
# [1297]	validation_0-rmse:4.20139
# [1298]	validation_0-rmse:4.20089
# [1299]	validation_0-rmse:4.20075
# [1300]	validation_0-rmse:4.20051
# [1301]	validation_0-rmse:4.20009
# [1302]	validation_0-rmse:4.19982
# [1303]	validation_0-rmse:4.19982
# [1304]	validation_0-rmse:4.19925
# [1305]	validation_0-rmse:4.19907
# [1306]	validation_0-rmse:4.19867
# [1307]	validation_0-rmse:4.19837
# [1308]	validation_0-rmse:4.19814
# [1309]	validation_0-rmse:4.19787
# [1310]	validation_0-rmse:4.19739
# [1311]	validation_0-rmse:4.19704
# [1312]	validation_0-rmse:4.19683
# [1313]	validation_0-rmse:4.19647
# [1314]	validation_0-rmse:4.19633
# [1315]	validation_0-rmse:4.19608
# [1316]	validation_0-rmse:4.19587
# [1317]	validation_0-rmse:4.19573
# [1318]	validation_0-rmse:4.19552
# [1319]	validation_0-rmse:4.19534
# [1320]	validation_0-rmse:4.19503
# [1321]	validation_0-rmse:4.19501
# [1322]	validation_0-rmse:4.19492
# [1323]	validation_0-rmse:4.19478
# [1324]	validation_0-rmse:4.19468
# [1325]	validation_0-rmse:4.19450
# [1326]	validation_0-rmse:4.19416
# [1327]	validation_0-rmse:4.19388
# [1328]	validation_0-rmse:4.19361
# [1329]	validation_0-rmse:4.19348
# [1330]	validation_0-rmse:4.19324
# [1331]	validation_0-rmse:4.19307
# [1332]	validation_0-rmse:4.19284
# [1333]	validation_0-rmse:4.19257
# [1334]	validation_0-rmse:4.19225
# [1335]	validation_0-rmse:4.19206
# [1336]	validation_0-rmse:4.19199
# [1337]	validation_0-rmse:4.19174
# [1338]	validation_0-rmse:4.19152
# [1339]	validation_0-rmse:4.19097
# [1340]	validation_0-rmse:4.19090
# [1341]	validation_0-rmse:4.19072
# [1342]	validation_0-rmse:4.19058
# [1343]	validation_0-rmse:4.19025
# [1344]	validation_0-rmse:4.18999
# [1345]	validation_0-rmse:4.18967
# [1346]	validation_0-rmse:4.18959
# [1347]	validation_0-rmse:4.18932
# [1348]	validation_0-rmse:4.18922
# [1349]	validation_0-rmse:4.18906
# [1350]	validation_0-rmse:4.18895
# [1351]	validation_0-rmse:4.18864
# [1352]	validation_0-rmse:4.18784
# [1353]	validation_0-rmse:4.18765
# [1354]	validation_0-rmse:4.18726
# [1355]	validation_0-rmse:4.18726
# [1356]	validation_0-rmse:4.18666
# [1357]	validation_0-rmse:4.18637
# [1358]	validation_0-rmse:4.18604
# [1359]	validation_0-rmse:4.18575
# [1360]	validation_0-rmse:4.18554
# [1361]	validation_0-rmse:4.18527
# [1362]	validation_0-rmse:4.18517
# [1363]	validation_0-rmse:4.18487
# [1364]	validation_0-rmse:4.18442
# [1365]	validation_0-rmse:4.18403
# [1366]	validation_0-rmse:4.18394
# [1367]	validation_0-rmse:4.18372
# [1368]	validation_0-rmse:4.18339
# [1369]	validation_0-rmse:4.18315
# [1370]	validation_0-rmse:4.18297
# [1371]	validation_0-rmse:4.18288
# [1372]	validation_0-rmse:4.18270
# [1373]	validation_0-rmse:4.18227
# [1374]	validation_0-rmse:4.18213
# [1375]	validation_0-rmse:4.18169
# [1376]	validation_0-rmse:4.18125
# [1377]	validation_0-rmse:4.18087
# [1378]	validation_0-rmse:4.18063
# [1379]	validation_0-rmse:4.18049
# [1380]	validation_0-rmse:4.18020
# [1381]	validation_0-rmse:4.17997
# [1382]	validation_0-rmse:4.17967
# [1383]	validation_0-rmse:4.17958
# [1384]	validation_0-rmse:4.17916
# [1385]	validation_0-rmse:4.17904
# [1386]	validation_0-rmse:4.17852
# [1387]	validation_0-rmse:4.17801
# [1388]	validation_0-rmse:4.17783
# [1389]	validation_0-rmse:4.17768
# [1390]	validation_0-rmse:4.17757
# [1391]	validation_0-rmse:4.17723
# [1392]	validation_0-rmse:4.17719
# [1393]	validation_0-rmse:4.17711
# [1394]	validation_0-rmse:4.17697
# [1395]	validation_0-rmse:4.17680
# [1396]	validation_0-rmse:4.17660
# [1397]	validation_0-rmse:4.17649
# [1398]	validation_0-rmse:4.17627
# [1399]	validation_0-rmse:4.17593
# [1400]	validation_0-rmse:4.17579
# [1401]	validation_0-rmse:4.17514
# [1402]	validation_0-rmse:4.17513
# [1403]	validation_0-rmse:4.17496
# [1404]	validation_0-rmse:4.17490
# [1405]	validation_0-rmse:4.17485
# [1406]	validation_0-rmse:4.17458
# [1407]	validation_0-rmse:4.17444
# [1408]	validation_0-rmse:4.17438
# [1409]	validation_0-rmse:4.17419
# [1410]	validation_0-rmse:4.17394
# [1411]	validation_0-rmse:4.17379
# [1412]	validation_0-rmse:4.17362
# [1413]	validation_0-rmse:4.17355
# [1414]	validation_0-rmse:4.17347
# [1415]	validation_0-rmse:4.17326
# [1416]	validation_0-rmse:4.17317
# [1417]	validation_0-rmse:4.17270
# [1418]	validation_0-rmse:4.17214
# [1419]	validation_0-rmse:4.17213
# [1420]	validation_0-rmse:4.17179
# [1421]	validation_0-rmse:4.17144
# [1422]	validation_0-rmse:4.17129
# [1423]	validation_0-rmse:4.17113
# [1424]	validation_0-rmse:4.17066
# [1425]	validation_0-rmse:4.17044
# [1426]	validation_0-rmse:4.17033
# [1427]	validation_0-rmse:4.17009
# [1428]	validation_0-rmse:4.16993
# [1429]	validation_0-rmse:4.16962
# [1430]	validation_0-rmse:4.16959
# [1431]	validation_0-rmse:4.16947
# [1432]	validation_0-rmse:4.16922
# [1433]	validation_0-rmse:4.16917
# [1434]	validation_0-rmse:4.16901
# [1435]	validation_0-rmse:4.16881
# [1436]	validation_0-rmse:4.16864
# [1437]	validation_0-rmse:4.16819
# [1438]	validation_0-rmse:4.16802
# [1439]	validation_0-rmse:4.16798
# [1440]	validation_0-rmse:4.16786
# [1441]	validation_0-rmse:4.16778
# [1442]	validation_0-rmse:4.16758
# [1443]	validation_0-rmse:4.16716
# [1444]	validation_0-rmse:4.16700
# [1445]	validation_0-rmse:4.16671
# [1446]	validation_0-rmse:4.16637
# [1447]	validation_0-rmse:4.16633
# [1448]	validation_0-rmse:4.16618
# [1449]	validation_0-rmse:4.16599
# [1450]	validation_0-rmse:4.16570
# [1451]	validation_0-rmse:4.16550
# [1452]	validation_0-rmse:4.16547
# [1453]	validation_0-rmse:4.16528
# [1454]	validation_0-rmse:4.16490
# [1455]	validation_0-rmse:4.16471
# [1456]	validation_0-rmse:4.16454
# [1457]	validation_0-rmse:4.16433
# [1458]	validation_0-rmse:4.16389
# [1459]	validation_0-rmse:4.16319
# [1460]	validation_0-rmse:4.16310
# [1461]	validation_0-rmse:4.16296
# [1462]	validation_0-rmse:4.16271
# [1463]	validation_0-rmse:4.16258
# [1464]	validation_0-rmse:4.16193
# [1465]	validation_0-rmse:4.16177
# [1466]	validation_0-rmse:4.16161
# [1467]	validation_0-rmse:4.16147
# [1468]	validation_0-rmse:4.16102
# [1469]	validation_0-rmse:4.16076
# [1470]	validation_0-rmse:4.16070
# [1471]	validation_0-rmse:4.16052
# [1472]	validation_0-rmse:4.16036
# [1473]	validation_0-rmse:4.15997
# [1474]	validation_0-rmse:4.15954
# [1475]	validation_0-rmse:4.15927
# [1476]	validation_0-rmse:4.15910
# [1477]	validation_0-rmse:4.15895
# ...
# [1519]	validation_0-rmse:4.14990
# [1520]	validation_0-rmse:4.14985
# [1521]	validation_0-rmse:4.14961
# [1522]	validation_0-rmse:4.14947
# [1523]	validation_0-rmse:4.14912
# [1524]	validation_0-rmse:4.14886
# [1525]	validation_0-rmse:4.14862
# [1526]	validation_0-rmse:4.14830
# [1527]	validation_0-rmse:4.14807
# [1528]	validation_0-rmse:4.14777
# [1529]	validation_0-rmse:4.14765
# [1530]	validation_0-rmse:4.14733
# [1531]	validation_0-rmse:4.14724
# [1532]	validation_0-rmse:4.14718
# [1533]	validation_0-rmse:4.14673
# [1534]	validation_0-rmse:4.14673
# [1535]	validation_0-rmse:4.14656
# [1536]	validation_0-rmse:4.14632
# [1537]	validation_0-rmse:4.14610
# [1538]	validation_0-rmse:4.14586
# [1539]	validation_0-rmse:4.14569
# [1540]	validation_0-rmse:4.14544
# [1541]	validation_0-rmse:4.14503
# [1542]	validation_0-rmse:4.14490
# [1543]	validation_0-rmse:4.14486
# [1544]	validation_0-rmse:4.14462
# [1545]	validation_0-rmse:4.14446
# [1546]	validation_0-rmse:4.14440
# [1547]	validation_0-rmse:4.14423
# [1548]	validation_0-rmse:4.14411
# [1549]	validation_0-rmse:4.14401
# [1550]	validation_0-rmse:4.14398
# [1551]	validation_0-rmse:4.14361
# [1552]	validation_0-rmse:4.14337
# [1553]	validation_0-rmse:4.14333
# [1554]	validation_0-rmse:4.14329
# [1555]	validation_0-rmse:4.14320
# [1556]	validation_0-rmse:4.14289
# [1557]	validation_0-rmse:4.14277
# [1558]	validation_0-rmse:4.14273
# [1559]	validation_0-rmse:4.14248
# [1560]	validation_0-rmse:4.14224
# [1561]	validation_0-rmse:4.14211
# [1562]	validation_0-rmse:4.14190
# [1563]	validation_0-rmse:4.14179
# [1564]	validation_0-rmse:4.14180
# [1565]	validation_0-rmse:4.14178
# [1566]	validation_0-rmse:4.14148
# [1567]	validation_0-rmse:4.14133
# [1568]	validation_0-rmse:4.14125
# [1569]	validation_0-rmse:4.14115
# [1570]	validation_0-rmse:4.14111
# [1571]	validation_0-rmse:4.14065
# [1572]	validation_0-rmse:4.14054
# [1573]	validation_0-rmse:4.14039
# [1574]	validation_0-rmse:4.14035
# [1575]	validation_0-rmse:4.14030
# [1576]	validation_0-rmse:4.14009
# [1577]	validation_0-rmse:4.13996
# [1578]	validation_0-rmse:4.13988
# [1579]	validation_0-rmse:4.13978
# [1580]	validation_0-rmse:4.13966
# [1581]	validation_0-rmse:4.13962
# [1582]	validation_0-rmse:4.13955
# [1583]	validation_0-rmse:4.13950
# [1584]	validation_0-rmse:4.13921
# [1585]	validation_0-rmse:4.13901
# [1586]	validation_0-rmse:4.13895
# [1587]	validation_0-rmse:4.13881
# [1588]	validation_0-rmse:4.13883
# [1589]	validation_0-rmse:4.13846
# [1590]	validation_0-rmse:4.13825
# [1591]	validation_0-rmse:4.13797
# [1592]	validation_0-rmse:4.13760
# [1593]	validation_0-rmse:4.13757
# [1594]	validation_0-rmse:4.13731
# [1595]	validation_0-rmse:4.13730
# [1596]	validation_0-rmse:4.13728
# [1597]	validation_0-rmse:4.13712
# [1598]	validation_0-rmse:4.13708
# [1599]	validation_0-rmse:4.13670
# [1600]	validation_0-rmse:4.13656
# [1601]	validation_0-rmse:4.13647
# [1602]	validation_0-rmse:4.13630
# [1603]	validation_0-rmse:4.13597
# [1604]	validation_0-rmse:4.13584
# [1605]	validation_0-rmse:4.13567
# [1606]	validation_0-rmse:4.13560
# [1607]	validation_0-rmse:4.13518
# [1608]	validation_0-rmse:4.13508
# [1609]	validation_0-rmse:4.13508
# [1610]	validation_0-rmse:4.13508
# [1611]	validation_0-rmse:4.13479
# [1612]	validation_0-rmse:4.13476
# [1613]	validation_0-rmse:4.13456
# [1614]	validation_0-rmse:4.13457
# [1615]	validation_0-rmse:4.13437
# [1616]	validation_0-rmse:4.13414
# [1617]	validation_0-rmse:4.13397
# [1618]	validation_0-rmse:4.13391
# [1619]	validation_0-rmse:4.13383
# [1620]	validation_0-rmse:4.13371
# [1621]	validation_0-rmse:4.13338
# [1622]	validation_0-rmse:4.13329
# [1623]	validation_0-rmse:4.13299
# [1624]	validation_0-rmse:4.13293
# [1625]	validation_0-rmse:4.13281
# [1626]	validation_0-rmse:4.13262
# [1627]	validation_0-rmse:4.13248
# [1628]	validation_0-rmse:4.13235
# [1629]	validation_0-rmse:4.13223
# [1630]	validation_0-rmse:4.13210
# [1631]	validation_0-rmse:4.13152
# [1632]	validation_0-rmse:4.13145
# [1633]	validation_0-rmse:4.13120
# [1634]	validation_0-rmse:4.13099
# [1635]	validation_0-rmse:4.13066
# [1636]	validation_0-rmse:4.13052
# [1637]	validation_0-rmse:4.13030
# [1638]	validation_0-rmse:4.13004
# [1639]	validation_0-rmse:4.12988
# [1640]	validation_0-rmse:4.12961
# [1641]	validation_0-rmse:4.12959
# [1642]	validation_0-rmse:4.12907
# [1643]	validation_0-rmse:4.12897
# [1644]	validation_0-rmse:4.12890
# [1645]	validation_0-rmse:4.12860
# [1646]	validation_0-rmse:4.12840
# [1647]	validation_0-rmse:4.12841
# [1648]	validation_0-rmse:4.12821
# [1649]	validation_0-rmse:4.12812
# [1650]	validation_0-rmse:4.12793
# [1651]	validation_0-rmse:4.12773
# [1652]	validation_0-rmse:4.12767
# [1653]	validation_0-rmse:4.12742
# [1654]	validation_0-rmse:4.12724
# [1655]	validation_0-rmse:4.12714
# [1656]	validation_0-rmse:4.12681
# [1657]	validation_0-rmse:4.12646
# [1658]	validation_0-rmse:4.12633
# [1659]	validation_0-rmse:4.12577
# [1660]	validation_0-rmse:4.12553
# [1661]	validation_0-rmse:4.12546
# [1662]	validation_0-rmse:4.12518
# [1663]	validation_0-rmse:4.12504
# [1664]	validation_0-rmse:4.12491
# [1665]	validation_0-rmse:4.12485
# [1666]	validation_0-rmse:4.12471
# [1667]	validation_0-rmse:4.12466
# [1668]	validation_0-rmse:4.12468
# [1669]	validation_0-rmse:4.12451
# [1670]	validation_0-rmse:4.12445
# [1671]	validation_0-rmse:4.12437
# [1672]	validation_0-rmse:4.12422
# [1673]	validation_0-rmse:4.12413
# [1674]	validation_0-rmse:4.12408
# [1675]	validation_0-rmse:4.12370
# [1676]	validation_0-rmse:4.12362
# [1677]	validation_0-rmse:4.12340
# [1678]	validation_0-rmse:4.12326
# [1679]	validation_0-rmse:4.12300
# [1680]	validation_0-rmse:4.12295
# [1681]	validation_0-rmse:4.12271
# [1682]	validation_0-rmse:4.12254
# [1683]	validation_0-rmse:4.12225
# [1684]	validation_0-rmse:4.12167
# [1685]	validation_0-rmse:4.12165
# [1686]	validation_0-rmse:4.12161
# [1687]	validation_0-rmse:4.12156
# [1688]	validation_0-rmse:4.12143
# [1689]	validation_0-rmse:4.12107
# [1690]	validation_0-rmse:4.12076
# [1691]	validation_0-rmse:4.12065
# [1692]	validation_0-rmse:4.12037
# [1693]	validation_0-rmse:4.12014
# [1694]	validation_0-rmse:4.12004
# [1695]	validation_0-rmse:4.12000
# [1696]	validation_0-rmse:4.11973
# [1697]	validation_0-rmse:4.11976
# [1698]	validation_0-rmse:4.11951
# [1699]	validation_0-rmse:4.11902
# [1700]	validation_0-rmse:4.11891
# [1701]	validation_0-rmse:4.11876
# [1702]	validation_0-rmse:4.11865
# [1703]	validation_0-rmse:4.11857
# [1704]	validation_0-rmse:4.11823
# [1705]	validation_0-rmse:4.11806
# [1706]	validation_0-rmse:4.11787
# [1707]	validation_0-rmse:4.11754
# [1708]	validation_0-rmse:4.11720
# [1709]	validation_0-rmse:4.11701
# [1710]	validation_0-rmse:4.11665
# [1711]	validation_0-rmse:4.11638
# [1712]	validation_0-rmse:4.11605
# [1713]	validation_0-rmse:4.11598
# [1714]	validation_0-rmse:4.11589
# [1715]	validation_0-rmse:4.11559
# [1716]	validation_0-rmse:4.11535
# [1717]	validation_0-rmse:4.11521
# [1718]	validation_0-rmse:4.11519
# [1719]	validation_0-rmse:4.11521
# [1720]	validation_0-rmse:4.11488
# [1721]	validation_0-rmse:4.11475
# [1722]	validation_0-rmse:4.11470
# [1723]	validation_0-rmse:4.11465
# [1724]	validation_0-rmse:4.11456
# [1725]	validation_0-rmse:4.11431
# [1726]	validation_0-rmse:4.11389
# [1727]	validation_0-rmse:4.11383
# [1728]	validation_0-rmse:4.11357
# [1729]	validation_0-rmse:4.11330
# [1730]	validation_0-rmse:4.11309
# [1731]	validation_0-rmse:4.11299
# [1732]	validation_0-rmse:4.11274
# [1733]	validation_0-rmse:4.11222
# [1734]	validation_0-rmse:4.11218
# [1735]	validation_0-rmse:4.11216
# [1736]	validation_0-rmse:4.11204
# [1737]	validation_0-rmse:4.11197
# [1738]	validation_0-rmse:4.11193
# [1739]	validation_0-rmse:4.11188
# [1740]	validation_0-rmse:4.11174
# [1741]	validation_0-rmse:4.11171
# [1742]	validation_0-rmse:4.11147
# [1743]	validation_0-rmse:4.11146
# [1744]	validation_0-rmse:4.11118
# [1745]	validation_0-rmse:4.11094
# [1746]	validation_0-rmse:4.11084
# [1747]	validation_0-rmse:4.11075
# [1748]	validation_0-rmse:4.11074
# [1749]	validation_0-rmse:4.11043
# [1750]	validation_0-rmse:4.11033
# [1751]	validation_0-rmse:4.11036
# [1752]	validation_0-rmse:4.11012
# [1753]	validation_0-rmse:4.10997
# [1754]	validation_0-rmse:4.10966
# [1755]	validation_0-rmse:4.10962
# [1756]	validation_0-rmse:4.10958
# [1757]	validation_0-rmse:4.10951
# [1758]	validation_0-rmse:4.10940
# [1759]	validation_0-rmse:4.10892
# [1760]	validation_0-rmse:4.10873
# [1761]	validation_0-rmse:4.10873
# [1762]	validation_0-rmse:4.10859
# [1763]	validation_0-rmse:4.10835
# [1764]	validation_0-rmse:4.10828
# [1765]	validation_0-rmse:4.10825
# [1766]	validation_0-rmse:4.10818
# [1767]	validation_0-rmse:4.10811
# [1768]	validation_0-rmse:4.10804
# [1769]	validation_0-rmse:4.10788
# [1770]	validation_0-rmse:4.10753
# [1771]	validation_0-rmse:4.10748
# [1772]	validation_0-rmse:4.10722
# [1773]	validation_0-rmse:4.10698
# [1774]	validation_0-rmse:4.10694
# [1775]	validation_0-rmse:4.10689
# [1776]	validation_0-rmse:4.10669
# [1777]	validation_0-rmse:4.10665
# [1778]	validation_0-rmse:4.10663
# [1779]	validation_0-rmse:4.10638
# [1780]	validation_0-rmse:4.10625
# [1781]	validation_0-rmse:4.10620
# [1782]	validation_0-rmse:4.10612
# [1783]	validation_0-rmse:4.10594
# [1784]	validation_0-rmse:4.10590
# [1785]	validation_0-rmse:4.10569
# [1786]	validation_0-rmse:4.10570
# [1787]	validation_0-rmse:4.10563
# [1788]	validation_0-rmse:4.10550
# [1789]	validation_0-rmse:4.10543
# [1790]	validation_0-rmse:4.10531
# [1791]	validation_0-rmse:4.10505
# [1792]	validation_0-rmse:4.10500
# [1793]	validation_0-rmse:4.10500
# [1794]	validation_0-rmse:4.10493
# [1795]	validation_0-rmse:4.10479
# [1796]	validation_0-rmse:4.10469
# [1797]	validation_0-rmse:4.10459
# [1798]	validation_0-rmse:4.10436
# [1799]	validation_0-rmse:4.10402
# [1800]	validation_0-rmse:4.10403
# [1801]	validation_0-rmse:4.10394
# [1802]	validation_0-rmse:4.10394
# [1803]	validation_0-rmse:4.10370
# [1804]	validation_0-rmse:4.10350
# [1805]	validation_0-rmse:4.10338
# [1806]	validation_0-rmse:4.10333
# [1807]	validation_0-rmse:4.10328
# [1808]	validation_0-rmse:4.10309
# [1809]	validation_0-rmse:4.10304
# [1810]	validation_0-rmse:4.10295
# [1811]	validation_0-rmse:4.10276
# [1812]	validation_0-rmse:4.10268
# [1813]	validation_0-rmse:4.10244
# [1814]	validation_0-rmse:4.10238
# [1815]	validation_0-rmse:4.10230
# [1816]	validation_0-rmse:4.10164
# [1817]	validation_0-rmse:4.10142
# [1818]	validation_0-rmse:4.10134
# [1819]	validation_0-rmse:4.10135
# [1820]	validation_0-rmse:4.10122
# [1821]	validation_0-rmse:4.10108
# [1822]	validation_0-rmse:4.10102
# [1823]	validation_0-rmse:4.10084
# [1824]	validation_0-rmse:4.10073
# [1825]	validation_0-rmse:4.10049
# [1826]	validation_0-rmse:4.10035
# [1827]	validation_0-rmse:4.10014
# [1828]	validation_0-rmse:4.10015
# [1829]	validation_0-rmse:4.10004
# [1830]	validation_0-rmse:4.09980
# [1831]	validation_0-rmse:4.09956
# [1832]	validation_0-rmse:4.09941
# [1833]	validation_0-rmse:4.09941
# [1834]	validation_0-rmse:4.09927
# [1835]	validation_0-rmse:4.09899
# [1836]	validation_0-rmse:4.09894
# [1837]	validation_0-rmse:4.09887
# [1838]	validation_0-rmse:4.09881
# [1839]	validation_0-rmse:4.09877
# [1840]	validation_0-rmse:4.09860
# [1841]	validation_0-rmse:4.09846
# [1842]	validation_0-rmse:4.09820
# [1843]	validation_0-rmse:4.09812
# [1844]	validation_0-rmse:4.09808
# [1845]	validation_0-rmse:4.09791
# [1846]	validation_0-rmse:4.09767
# [1847]	validation_0-rmse:4.09741
# [1848]	validation_0-rmse:4.09712
# [1849]	validation_0-rmse:4.09710
# [1850]	validation_0-rmse:4.09701
# [1851]	validation_0-rmse:4.09692
# [1852]	validation_0-rmse:4.09675
# [1853]	validation_0-rmse:4.09674
# [1854]	validation_0-rmse:4.09665
# [1855]	validation_0-rmse:4.09639
# [1856]	validation_0-rmse:4.09630
# [1857]	validation_0-rmse:4.09621
# [1858]	validation_0-rmse:4.09614
# [1859]	validation_0-rmse:4.09599
# [1860]	validation_0-rmse:4.09599
# [1861]	validation_0-rmse:4.09595
# [1862]	validation_0-rmse:4.09566
# [1863]	validation_0-rmse:4.09559
# [1864]	validation_0-rmse:4.09557
# [1865]	validation_0-rmse:4.09554
# [1866]	validation_0-rmse:4.09545
# [1867]	validation_0-rmse:4.09538
# [1868]	validation_0-rmse:4.09526
# [1869]	validation_0-rmse:4.09527
# [1870]	validation_0-rmse:4.09524
# [1871]	validation_0-rmse:4.09523
# [1872]	validation_0-rmse:4.09512
# [1873]	validation_0-rmse:4.09485
# [1874]	validation_0-rmse:4.09458
# [1875]	validation_0-rmse:4.09449
# [1876]	validation_0-rmse:4.09437
# [1877]	validation_0-rmse:4.09410
# [1878]	validation_0-rmse:4.09393
# [1879]	validation_0-rmse:4.09386
# [1880]	validation_0-rmse:4.09351
# [1881]	validation_0-rmse:4.09348
# [1882]	validation_0-rmse:4.09335
# [1883]	validation_0-rmse:4.09323
# [1884]	validation_0-rmse:4.09311
# [1885]	validation_0-rmse:4.09300
# [1886]	validation_0-rmse:4.09282
# [1887]	validation_0-rmse:4.09273
# [1888]	validation_0-rmse:4.09260
# [1889]	validation_0-rmse:4.09248
# [1890]	validation_0-rmse:4.09238
# [1891]	validation_0-rmse:4.09220
# [1892]	validation_0-rmse:4.09211
# [1893]	validation_0-rmse:4.09192
# [1894]	validation_0-rmse:4.09175
# [1895]	validation_0-rmse:4.09156
# [1896]	validation_0-rmse:4.09142
# [1897]	validation_0-rmse:4.09112
# [1898]	validation_0-rmse:4.09109
# [1899]	validation_0-rmse:4.09085
# [1900]	validation_0-rmse:4.09080
# [1901]	validation_0-rmse:4.09076
# [1902]	validation_0-rmse:4.09059
# [1903]	validation_0-rmse:4.09029
# [1904]	validation_0-rmse:4.09018
# [1905]	validation_0-rmse:4.09003
# [1906]	validation_0-rmse:4.08983
# [1907]	validation_0-rmse:4.08981
# [1908]	validation_0-rmse:4.08976
# [1909]	validation_0-rmse:4.08967
# [1910]	validation_0-rmse:4.08930
# [1911]	validation_0-rmse:4.08928
# [1912]	validation_0-rmse:4.08926
# [1913]	validation_0-rmse:4.08916
# [1914]	validation_0-rmse:4.08917
# [1915]	validation_0-rmse:4.08911
# [1916]	validation_0-rmse:4.08891
# [1917]	validation_0-rmse:4.08875
# [1918]	validation_0-rmse:4.08870
# [1919]	validation_0-rmse:4.08855
# [1920]	validation_0-rmse:4.08818
# [1921]	validation_0-rmse:4.08820
# [1922]	validation_0-rmse:4.08794
# [1923]	validation_0-rmse:4.08763
# [1924]	validation_0-rmse:4.08751
# [1925]	validation_0-rmse:4.08747
# [1926]	validation_0-rmse:4.08739
# [1927]	validation_0-rmse:4.08732
# [1928]	validation_0-rmse:4.08727
# [1929]	validation_0-rmse:4.08695
# [1930]	validation_0-rmse:4.08690
# [1931]	validation_0-rmse:4.08688
# [1932]	validation_0-rmse:4.08665
# [1933]	validation_0-rmse:4.08660
# [1934]	validation_0-rmse:4.08651
# [1935]	validation_0-rmse:4.08638
# [1936]	validation_0-rmse:4.08632
# [1937]	validation_0-rmse:4.08599
# [1938]	validation_0-rmse:4.08593
# [1939]	validation_0-rmse:4.08568
# [1940]	validation_0-rmse:4.08554
# [1941]	validation_0-rmse:4.08539
# [1942]	validation_0-rmse:4.08541
# [1943]	validation_0-rmse:4.08525
# [1944]	validation_0-rmse:4.08515
# [1945]	validation_0-rmse:4.08511
# [1946]	validation_0-rmse:4.08502
# [1947]	validation_0-rmse:4.08501
# [1948]	validation_0-rmse:4.08496
# [1949]	validation_0-rmse:4.08476
# [1950]	validation_0-rmse:4.08476
# [1951]	validation_0-rmse:4.08457
# [1952]	validation_0-rmse:4.08453
# [1953]	validation_0-rmse:4.08436
# [1954]	validation_0-rmse:4.08429
# [1955]	validation_0-rmse:4.08427
# [1956]	validation_0-rmse:4.08409
# [1957]	validation_0-rmse:4.08401
# [1958]	validation_0-rmse:4.08388
# [1959]	validation_0-rmse:4.08379
# [1960]	validation_0-rmse:4.08371
# [1961]	validation_0-rmse:4.08356
# [1962]	validation_0-rmse:4.08335
# [1963]	validation_0-rmse:4.08304
# [1964]	validation_0-rmse:4.08286
# [1965]	validation_0-rmse:4.08261
# [1966]	validation_0-rmse:4.08252
# [1967]	validation_0-rmse:4.08223
# [1968]	validation_0-rmse:4.08214
# [1969]	validation_0-rmse:4.08192
# [1970]	validation_0-rmse:4.08188
# [1971]	validation_0-rmse:4.08190
# [1972]	validation_0-rmse:4.08183
# [1973]	validation_0-rmse:4.08185
# [1974]	validation_0-rmse:4.08184
# [1975]	validation_0-rmse:4.08181
# [1976]	validation_0-rmse:4.08165
# [1977]	validation_0-rmse:4.08155
# [1978]	validation_0-rmse:4.08137
# [1979]	validation_0-rmse:4.08133
# [1980]	validation_0-rmse:4.08120
# [1981]	validation_0-rmse:4.08093
# [1982]	validation_0-rmse:4.08070
# [1983]	validation_0-rmse:4.08066
# [1984]	validation_0-rmse:4.08054
# [1985]	validation_0-rmse:4.08047
# [1986]	validation_0-rmse:4.08043
# [1987]	validation_0-rmse:4.08033
# [1988]	validation_0-rmse:4.08018
# [1989]	validation_0-rmse:4.07998
# [1990]	validation_0-rmse:4.07990
# [1991]	validation_0-rmse:4.07979
# [1992]	validation_0-rmse:4.07964
# [1993]	validation_0-rmse:4.07946
# [1994]	validation_0-rmse:4.07927
# [1995]	validation_0-rmse:4.07919
# [1996]	validation_0-rmse:4.07910
# [1997]	validation_0-rmse:4.07894
# [1998]	validation_0-rmse:4.07885
# [1999]	validation_0-rmse:4.07861
# Mean Squared Error: 16.6280847347397
# Root Mean Squared Error: 4.077754864473795
# Euclidian distance Error: 4.8672136408031825

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from math import sqrt
import joblib  # Import joblib
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
from joblib import dump

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)


# Model initialization and training with verbose output
model = RandomForestRegressor(n_estimators=100, random_state=42, verbose=3)
model.fit(X_train, Y_train)

dump(model, 'random_forest_model.joblib')

# Predicting the targets
predictions = model.predict(X_test)
mse = mean_squared_error(Y_test, predictions)
print(f"Mean Squared Error: {mse}")
rmse = sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
euclidian= euclidean_distance_error(Y_test, predictions)
print(f"Euclidian distance Error: {euclidian}")
# Out:
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# [Parallel(n_jobs=1)]: Done  31 tasks      | elapsed: 11.2min
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done  31 tasks      | elapsed:    1.2s
# Mean Squared Error: 15.578667301242266
# Root Mean Squared Error: 3.9469820497745194
# Euclidian distance Error: 4.504138469275587
